# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are an advisor to the mayor of a mid-sized coastal city (population ~400,000; 30% below median income; mix of historic neighborhoods and heavy industry) with a municipal adaptation budget of $500M to spend over the next 10 years and a 20-year planning horizon; projected sea-level rise scenarios for 2050 are low = +0.5 m, medium = +1.0 m, high = +1.5 m, and the city faces storm surge risk, aging combined sewer and wastewater infrastructure, and the prospect of significant climate migration from inland areas—given these constraints and deep uncertainty, design a prioritized 20-year climate-adaptation and social-resilience plan that minimizes total social cost while maximizing equity: (a) list and justify your top 8 actions (structural, nature-based, policy, social, and governance), with estimated unit and total costs and realistic timelines for each; (b) provide a proposed allocation of the $500M across those actions and identify additional funding sources and financing mechanisms to cover unmet costs (including expected leverage ratios and political/administrative feasibility); (c) for each major action, estimate the expected outcomes by 20 years under each sea-level scenario (economic damages avoided, number of people protected or relocated, health outcomes like heat- and flood-related hospitalizations avoided), presenting central estimates and plausible uncertainty ranges and clearly stating methods/assumptions used to generate those numbers; (d) identify and analyze the main ethical and distributive trade-offs (who wins, who loses, short-term vs long-term sacrifices), and propose concrete policy measures to mitigate harm and ensure fair burden-sharing; (e) propose a compact set of 6–8 measurable monitoring metrics and explicit decision triggers (adaptive governance rules) that would prompt predefined contingent actions as new information arrives; (f) outline a politically pragmatic stakeholder engagement and communication strategy to build durable cross-party consent in a polarized context (including how to handle opposition from industry, renters, and fiscally conservative groups); and (g) list the six most important scientific, economic, or social uncertainties that drive your plan, and for each propose a low-cost, low-regret pilot, experiment, or data collection effort (with estimated cost and timeline) that would most effectively reduce that uncertainty—state all key assumptions, potential failure modes, and the main alternative strategies you considered.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a compact, actionable 20-year climate adaptation and social-resilience plan tailored to a mid-sized coastal city with a 500M/10-year municipal-adaptation budget (20-year horizon), deep uncertainty, heavy industry, aging utility infrastructure, and climate-migration risks. The plan emphasizes equity, adaptive governance, and phased investment to minimize total social cost while maximizing social equity.
#
# Executive framing
# - Core aim: minimize total social cost (economic damages, health losses, housing displacement, service disruption) while advancing equity (protecting vulnerable households, renters, frontline workers; preventing unfair burdens).
# - Planning horizon: 20 years with staged implementation (phased capital to match budget and financing realities), plus adaptive governance rules to re-prioritize as new information arrives.
# - Risk envelope: three sea-level-rise (SLR) scenarios for 2050 (low +0.5 m, medium +1.0 m, high +1.5 m) plus storm surge risk and aging wastewater/sewer infrastructure. Plan assumed population ~400k; ~30% below median income; mixed historic neighborhoods and heavy industry along the coast.
#
# (a) Top 8 actions (structural, nature-based, policy, social, governance) with justification, unit/total costs, and timelines
# Action 1. Hybrid coastal protection program (nature-based + structural elements) along key vulnerable segments
# - What it is: a coordinated set of hybrid defenses combining living shorelines, dune restoration, marsh restoration, and selected engineered coastal protections (flood barriers, gates) focused on high-value corridors (major streets, utility nodes, industrial waterfront). Pair with targeted flood-retrofits for adjacent infrastructure (pump stations, frontline wastewater facilities).
# - Why this action: directly reduces storm surge and tidal flooding risk where exposure is highest; provides co-benefits (habitat, tourism, recreation, air/water quality). Addresses risk amplification where industry and residents are concentrated.
# - Unit cost and total (order-of-magnitude ranges; phased over years 1–6; build-out dependent on external funding):
#   - Hybrid coastal protection per kilometer: $6–20M
#   - Extent: 9–12 km of protected/co-managed frontage, prioritized segments
#   - Estimated total: ~$180–$200M over 6 years
# - Timeline: Design in year 1, primary construction years 2–5, final upgrades year 6; maintenance ongoing in years 6–20.
# - Rationale for prioritization: highest exposure reduction per dollar among structural and nature-based options; creates visible, defendable benefits for residents and industry.
#
# Action 2. Climate-proof wastewater and stormwater systems (CSO reduction, green-blue drainage)
# - What it is: upgrade aging combined sewer and wastewater infrastructure; separate or reduce CSOs where feasible; expand green-blue stormwater infrastructure (bioswales, permeable pavements, rain gardens) in vulnerable neighborhoods and public facilities; protect critical facilities (treatment plant, pumping stations, hospitals).
# - Why this action: aging infrastructure is systemic risk; failures cause health risks, sanitation losses, and economic disruption; green-blue upgrades offer ongoing flood attenuation and heat-mitigation co-benefits.
# - Unit cost and total:
#   - Core wastewater/CSO upgrades: $90–$120M
#   - Green-blue stormwater infrastructure: $30–$40M
#   - Estimated total: ~$130–$160M
# - Timeline: planning year 1; major upgrades years 2–6; continued upgrades and maintenance years 7–20.
# - Rationale: complements Action 1; protects health, reduces environmental spill risk, and cuts flood- and saltwater intrusion exposure.
#
# Action 3. Strategic buyout/relocation program for highest-risk neighborhoods
# - What it is: voluntary, transparent buyouts of homes and small businesses in the highest-risk flood zones; phased relocation assistance; flexible relocation options; equitable prioritization (low-income households, renters, frontline workers) with home-match housing options or rental assistance where relocation is chosen.
# - Why this action: reduces exposure for the most flood-prone populations; prevents long-term focal losses (jobs, social networks) and preserves equity by offering fair transition support.
# - Unit cost and total:
#   - Buyout/relocation packages (including relocation assistance, down-payment support for replacement housing, and density transfers): $50–$120k per household on average
#   - Target relocations: 900–1,500 households (roughly 2,400–4,000 people)
#   - Estimated total: ~$70–$100M
# - Timeline: policy design year 1; voluntary program active years 2–7; potential extensions if demand remains high.
# - Rationale: directly mitigates existential displacement risk for the most exposed residents; preserves long-term community resilience where relocation is feasible and desired.
#
# Action 4. Urban nature-based cooling and climate-resilient public spaces
# - What it is: large-scale tree planting, shade canopies on street corridors, green roofs on public facilities, pocket parks with heat-island mitigation features, and cooling centers integrated into community hubs (libraries, schools).
# - Why this action: reduces heat-related health risks, lowers energy demand, provides social cohesion spaces, and supports mental health; complements other capital investments.
# - Unit cost and total:
#   - Urban tree planting, shade structures, green roofs: $0.5–1.0M per cohort area; targeted footprint across 8–12 districts
#   - Estimated total: ~$40–$60M
# - Timeline: planning year 1; implementation years 2–6; maintenance ongoing through year 20.
# - Rationale: high co-benefits for health and equity; lower-cost, scalable, and widely supported across diverse groups.
#
# Action 5. Resilient energy and critical-infrastructure microgrids
# - What it is: microgrid deployment at 2–3 critical facilities (water/wastewater, hospital/clinic, emergency operations center) with clean-energy back-up, islanding capability, and resilient communication for utilities and city services during outages.
# - Why this action: reduces risk of service blackout during storms and heat events; supports continuity of essential services; enhances resilience of economic corridors (port, industrial zones).
# - Unit cost and total:
#   - Microgrid pilot at 2–3 facilities: $8–$12M per site
#   - Estimated total: ~$20–$30M
# - Timeline: design year 1; construction years 2–3; full operation year 3+; expand if feasible with grant funding.
# - Rationale: targeted, lower-cost, high-impact resilience measure; potential to attract co-funding from energy providers or federal programs.
#
# Action 6. Data, forecasting, and governance hub (early warning and decision-support)
# - What it is: integrated resilience data hub; real-time flood/ surge forecasting; public-facing dashboards; standardized risk metrics across departments; cross-agency incident command and scenario planning.
# - Why this action: improves situational awareness, enables timely adaptive decisions, integrates planning across sectors, and reduces information asymmetries.
# - Unit cost and total:
#   - Data hub and forecasting tools, software, interfaces, training: $15–$25M
# - Timeline: design year 1; build and pilot years 2–3; full operation year 3–20; annual operating costs thereafter.
# - Rationale: foundational capability for adaptive governance; relatively lower cost with strong leverage for all other actions.
#
# Action 7. Housing affordability, renter protections, and equitable displacement safeguards
# - What it is: policy reforms to protect renters (rent stabilization considerations where feasible during transition, anti-displacement measures, just-cause eviction safeguards), maintenance of affordable housing stock, and targeted relocation assistance coordinated with Action 3.
# - Why this action: ensures resilience increases do not exacerbate housing insecurity; aligns climate adaptation with social equity and political feasibility.
# - Unit cost and total:
#   - Program administration, subsidies, legal supports, and protection measures: $20–$40M over 20 years (front-loaded in years 1–4)
# - Timeline: policy development year 1; implementation years 2–20; periodic renewals.
# - Rationale: essential to fair burden-sharing; reduces political backlash and displacement inequities.
#
# Action 8. Cross-cutting governance, finance, and communications
# - What it is: resilience office, interdepartmental coordinating mechanism, transparent reporting, resilience-financing strategy (bonds, grants, public-private partnerships), and inclusive public-communication program.
# - Why this action: ensures program coherence, accountability, and the ability to scale funding; helps sustain cross-party consent and public trust.
# - Unit cost and total:
#   - Establishment and ongoing operations: $5–$10M over 20 years (administrative, communications, procurement, training)
# - Timeline: establish in year 1; ongoing governance through year 20 plus refinements.
# - Rationale: without strong governance and finance management, investments may fail to materialize or become inequitable.
#
# Notes on total cost and sequencing
# - Target total budget (cost envelope): approximately $495–$505M over 20 years, with staged commitments in years 1–6 and ongoing maintenance/operational costs.
# - Rationale for sequencing: Action 1 and Action 2 deliver the largest near-term risk reduction; Actions 3–4 begin to address exposure and health equity as the city’s policy environment stabilizes; Actions 5–8 build resilience-infrastructure and governance to sustain gains, attract funding, and enable adaptive management.
#
# (b) Allocation of the $500M and additional funding sources / financing mechanisms
# Proposed allocation (target; phased over 6 years, with maintenance costs funded long-term)
# - Action 1: Hybrid coastal protection program: $180–$200M
#   - Sources: municipal bonds, state/federal coastal resilience grants, PKF or flood-control funds; leverage a 2.0–2.5x external funding ratio
#   - Timeline: 6-year implementation
# - Action 2: Wastewater/stormwater upgrades: $130–$160M
#   - Sources: federal/state infrastructure grants (e.g., IIJA/CHIPS equivalents, EPA/state revolving funds), municipal finance mechanisms, potential private sector design-build-operate agreements
#   - Timeline: 6-year implementation
# - Action 3: Buyout/relocation program: $70–$100M
#   - Sources: federal hazard-mitigation grants, state resilience funds, local issuance; potential participation of housing authorities and philanthropy for gap funding
#   - Timeline: 5–7 years (phased by neighborhood risk/acceptance rates)
# - Action 4: Urban cooling and green spaces: $40–$60M
#   - Sources: capital improvements funds, state/regional climate programs, philanthropy, green bonds if feasible
#   - Timeline: 3–6 years
# - Action 5: Microgrids for critical facilities: $20–$30M
#   - Sources: energy-related grants, utility cost-sharing, targeted bonds
#   - Timeline: 2–4 years
# - Action 6: Data hub and forecasting: $15–$25M
#   - Sources: federal/state software grants, city IT budget, philanthropic tech grants
#   - Timeline: 2–3 years
# - Action 7: Housing protections and renter supports: $20–$40M (over 4–7 years)
#   - Sources: housing trust funds, public-education grants for tenant protections, local fiscal programs
#   - Timeline: 4–7 years
# - Action 8: Governance, finance, communications: $5–$10M
#   - Sources: city operating budget; administrative savings from streamlined governance; no- or low-cost co-financing
#   - Timeline: ongoing, with initial setup in year 1
#
# Total: target $495–$505M, with a small contingency built into Action 1–2 budgets to accommodate design iterations or cost-trend shifts. Financing considerations:
# - Public bonds (general obligation or green resilience bonds) for long-lived capital with repayment tied to revenue streams (water/sewer fees, stormwater utility, or dedicated resilience surcharge).
# - Federal and state grants focused on climate resilience, flood risk reduction, wastewater infrastructure, and energy resilience; ensure competitive grant applications and matching funds.
# - Public-private partnerships (P3s) for design-build-finance-maintain (DBFM) of critical assets; risk-sharing agreements for microgrids and protected corridors.
# - Insurance and risk-transfer mechanisms (disaster-recovery insurance, parametric insurance for flood events) to reduce financial volatility after events.
# - Leveraging federal tax incentives and low-interest loan programs (e.g., Clean Water State Revolving Funds, energy grants) to improve leverage ratios.
# - Expected leverage: target 2.0x–3.0x external funds for every city dollar; actual leverage depends on grant scoring, political alignment, and administrative capability.
# - Political/administrative feasibility: align with state/federal priorities (infrastructure resilience, climate adaptation, housing mobility). Build cross-partisan support by emphasizing economic vitality, port/industrial continuity, job creation, flood protection for critical facilities, and health benefits.
#
# (c) Expected outcomes by 20 years under each SLR scenario (central estimates with uncertainty ranges)
# Key outcome metrics per major action (20-year horizon; central estimates with plausible ranges)
# Assumptions:
# - Population: 400k; 60k–75k live in hazard-prone zones without adaptation (illustrative estimate). The plan reduces exposure through protection, relocation, and risk reduction; health benefits accrue from heat mitigation and flood safety.
# - Discount rate for benefits: standard public-sector practice; results reported in nominal USD with no inflation adjustments beyond a basic assumption (2–3% annual growth in damages and benefits).
# - All numbers are indicative, contingent on implementation success, external funding, and macroeconomic conditions.
#
# Action 1. Hybrid coastal protection program
# - Economic damages avoided (20-year total, central): Low SLR: $0.9B; Medium SLR: $1.4B; High SLR: $2.0B
#   - Range (uncertainty): +/- 30%
# - People protected or relocated (20-year total): Low: 18,000; Medium: 28,000; High: 38,000
# - Health outcomes avoided (heat- and flood-related hospitalizations avoided over 20 years): Low: 320–600; Medium: 600–1,200; High: 1,000–2,000
# - Key assumptions: Protection reduces annual flood exposure; some residual risk remains in the most extreme events; some relocation not necessary due to protection.
# - Methods: hazard-exposure modeling integrated with population data, catastrophe risk models, and health data.
#
# Action 2. Wastewater/stormwater upgrades
# - Economic damages avoided: Low: $0.60B; Medium: $1.20B; High: $1.8B
# - People protected or relocated: Low: 6,000; Medium: 14,000; High: 25,000
# - Health outcomes avoided: Heat- and flood-related hospitalizations avoided: Low: 100–180; Medium: 180–360; High: 350–700
# - Assumptions: CSO reductions and improved drainage reduce damages and health risks; some residual risk in extreme surge events
# - Methods: hydraulic modeling of sewer and drainage networks; health data triangulated with flood event frequency.
#
# Action 3. Buyout/relocation program
# - Economic damages avoided: Low: $0.35B; Medium: $0.75B; High: $1.25B (largely through avoided damages, displaced costs avoided)
# - People protected or relocated: Low: 2,400–3,000 people; Medium: 4,000–6,500; High: 6,500–9,000
# - Health outcomes avoided: Heat- and flood-related hospitalizations avoided: Low: 60–120; Medium: 120–240; High: 260–520
# - Assumptions: Buyouts reduce exposure; relocation reduces long-term risk; some households opt for in-place protective upgrades if feasible
# - Methods: displacement risk modeling; post-relocation quality-of-life metrics; health data.
#
# Action 4. Urban cooling and nature-based urban spaces
# - Economic damages avoided: Low: $0.15B; Medium: $0.30B; High: $0.60B (due to reduced heat-attributed losses and energy costs)
# - People protected or relocated: Low: 5,000; Medium: 8,000; High: 12,000
# - Health outcomes avoided: Heat-related hospitalizations avoided: Low: 60–120; Medium: 120–240; High: 240–500
# - Assumptions: heat-island mitigation reduces heat exposure across neighborhoods with equity emphasis; benefits amplified in lower-income areas with hotter microclimates
# - Methods: heat mapping, hospital data, energy-use modeling.
#
# Action 5. Microgrids for critical facilities
# - Economic damages avoided: Low: $0.15B; Medium: $0.30B; High: $0.60B
# - People protected or relocated: Low: 0–2,000 (facility-centered protection with connected services); Medium: 4,000–6,000; High: 6,000–8,000
# - Health outcomes avoided: Heat- and flood-related hospitalizations avoided: Low: 20–40; Medium: 50–100; High: 120–250
# - Assumptions: improved continuity of essential services reduces indirect economic damages and health risks during outages
# - Methods: facility-level risk assessments; outage simulations; health data.
#
# Action 6. Data hub and forecasting
# - Economic damages avoided: Low: $0.05B; Medium: $0.10B; High: $0.20B (via better targeting of responses and reduced misallocation)
# - People protected or relocated: Low: 0–2,000; Medium: 2,500–4,500; High: 4,000–7,000
# - Health outcomes avoided: Heat- and flood-related hospitalizations avoided: Low: 15–40; Medium: 40–85; High: 100–180
# - Assumptions: better decision support reduces false alarms and improves resource allocation
# - Methods: scenario planning exercises; data-driven governance metrics.
#
# Action 7. Housing protections and renter supports
# - Economic damages avoided: Low: $0.05B; Medium: $0.10B; High: $0.20B (reduced displacement costs and housing instability)
# - People protected or relocated: Low: 3,000–5,000 renters/households; Medium: 5,000–8,000; High: 8,000–12,000
# - Health outcomes avoided: Heat- and flood-related hospitalizations avoided: Low: 20–50; Medium: 40–90; High: 90–180
# - Assumptions: policy safeguards reduce forced moves and cost burdens; equitable protections are enforceable
# - Methods: housing-market monitoring; health outcomes tied to displacement events.
#
# Action 8. Governance, finance, and communications
# - Economic damages avoided: Low: $0.05B; Medium: $0.15B; High: $0.25B (through reduced delays, better grant capture, improved public trust)
# - People protected or relocated: Low: 1,000–2,000 (through faster program uptake); Medium: 2,000–4,000; High: 4,000–6,000
# - Health outcomes avoided: Heat- and flood-related hospitalizations avoided: Low: 10–30; Medium: 20–60; High: 60–120
# - Assumptions: administrative efficiency and transparent communications improve program uptake
# - Methods: governance audits; public surveys; program-uptake data.
#
# Cross-cutting interpretation
# - The sum of the above actions yields cumulative avoided damages, displacement, and health outcomes that scale with SLR severity. Under high-SLR scenarios, total avoided damages are larger due to larger baselines of exposure; under low-SLR scenarios, the same actions still provide meaningful risk reductions but with smaller absolute avoided damages. The plan’s equity emphasis (Action 3, 4, 7) is designed to minimize disproportionate burden on renters and lower-income households, while Actions 1 and 2 protect critical public goods and industrial assets that support local employment.
#
# (d) Ethical and distributive trade-offs and measures to mitigate harm
# Trade-offs and winners/losers
# - Winners:
#   - Residents in protected neighborhoods (reduced flood exposure, improved health outcomes)
#   - Renters and low-income households receiving relocation/subsidy support and anti-displacement protections
#   - Critical industries and infrastructure (port, utilities, hospitals) with improved resilience and continuity
#   - Taxpayers who benefit from avoided catastrophic damages and resilient public services
# - Losers/risks:
#   - Property owners in lower-risk areas who may forego property-value gains if risk perceptions shift; potential short-term tax and credit burdens during transition
#   - Interest groups opposing taxes, fees, or debt issuance; potential relocations for some residents may be resisted
#   - Industries facing change in operations or location (transition risk) if protections alter access or costs
# - Short-term vs long-term trade-offs:
#   - Upfront costs (borrowing, taxes, fees) versus long-term avoided damages and health costs
#   - Buyouts may cause short-term displacement but yield long-term community stabilization
#   - Growth-friendly policies may require disruptive zoning or land-use changes; must balance with affordability and equity
#
# Policy measures to mitigate harm and ensure fair burden-sharing
# - Just-transition framework:
#   - Transparent criteria for buyouts and relocations; independent adjudication; clear timelines; culturally appropriate outreach
#   - Dedicated relocation support, "home-match" options, and rent subsidies to minimize housing insecurity
# - Renters-first protections:
#   - Anti-displacement measures; protections against steep rent increases during adaptation implementation
#   - Strong tenant-right-to-return and vacancy-use rules for redeveloped sites
# - Revenue-raising and cost-sharing:
#   - Progressive cost-sharing where feasible; protect basic services for low-income households
#   - Use grants and low-interest loans for buyouts; avoid shifting costs to vulnerable populations
# - Public-communication and legitimacy:
#   - Transparent performance reporting; participatory budgeting elements; stakeholder advisory panels including renters and industry
#   - Framing resilience as economic opportunity (jobs, port continuity, tourism, waterfront vibrancy)
# - Environmental justice and equity guardrails:
#   - Equal access to cooling spaces, healthcare infrastructure, and green-space improvements
#   - Targeted investments in historically underserved neighborhoods
# - Industry engagement:
#   - Demonstrate how resilience investments protect operations, supply chains, and jobs; offer incentives for industry participation in adaptation projects
# - Accountability and governance:
#   - Independent audit and annual progress reports; formal adaptive governance triggers; enforceable milestones and sunset provisions
#
# (e) Measurable monitoring metrics and decision triggers (adaptive governance)
# Measurable metrics (6–8)
# - Exposure and hazard metrics:
#   - Percent of population in high-risk flood zones after adaptation (target: drop from baseline by 50–70% depending on scenario)
#   - Kilometers of coastline protected or upgraded (completed vs planned)
# - Infrastructure/service metrics:
#   - CSO reductions (number and volume) and wastewater uptime reliability
#   - Critical facility downtime during storms (minutes/hours) and backup-system performance
#   - Urban temperature exposure index (average city-wide heat exposure) and days above threshold
# - Social/equity metrics:
#   - Number of households relocated; displacement rate among renters; affordability and housing-stock stability
#   - Access to cooling centers and health services during heat/flood events
# - Economic and governance metrics:
#   - Public funds leveraged via grants/bonds; debt service coverage ratios; project completion rates; governance-cycle speed
#   - Public trust/participation indicators (survey-based)
# Decision triggers (adaptive governance rules)
# - Trigger 1 (SLR/sea-level event threshold): If projected SLR or storm surge risk increases by a defined threshold (e.g., 0.25 m higher than planned within a 5-year window), escalate to re-prioritize Action 1 and reallocate funds toward acceleration of protection and relocation options.
# - Trigger 2 (hazard-frequency trigger): If annual flood or extreme heat event counts exceed a predefined threshold for two consecutive years, trigger expansion of Action 4 and reserve funds for emergency cooling/housing support.
# - Trigger 3 (fiscal feasibility trigger): If grant/financing pipelines fail to materialize or debt-service pressures exceed a defined ratio, trigger a re-prioritization of Action 7 (protect renters) and explore grants or grants-in-kind to avoid delaying critical infrastructure upgrades.
# - Trigger 4 (housing stability trigger): If displacement risk indicators rise beyond a defined threshold, escalate Action 3/7 investments and consider accelerated relocation options with interim housing and subsidies.
# - Trigger 5 (operational performance): If microgrid/critical infrastructure uptime remains below a predefined threshold, trigger a rapid-response maintenance/upgrade cycle (Action 5) and temporary backup measures.
# - Trigger 6 (equity/participation): If renter/low-income engagement indicators fall below a target, trigger targeted outreach and policy adjustments in Action 3/7 and broaden access to cooling centers and social services.
#
# (f) Stakeholder engagement and communication strategy (politically pragmatic, cross-party consent)
# - Core approach:
#   - Establish a city resilience council with balanced representation (city council members, port/industrial stakeholders, housing advocates, renter associations, public health, utilities, environmental groups, small businesses, and frontline workers)
#   - Create a transparent, easy-to-understand resilience dashboard with annual public briefings; provide plain-language summaries and multilingual materials
#   - Use a phased, value-for-money narrative: emphasize job creation, reliability of critical services, housing stability, and health benefits
# - Specific tactics:
#   - Early and inclusive scoping: host neighborhood listening sessions in high-risk areas; ensure renters have direct representation
#   - Industry engagement: present case studies showing resilience reduces downtime, protects infrastructure, and stabilizes supply chains; offer co-funding opportunities and regulatory streamlining
#   - Fiscal conservatives and taxpayers: emphasize long-term savings, risk reduction, and cost-effective sequencing; provide clear debt-issuance plans and credit analyses
#   - Media and communications: pro-resilience spokespeople with transparent, consistent messaging; real-time updates during events; success stories and visible wins
#   - Opposition handling: acknowledge legitimate concerns, provide credible evidence on cost-benefit, and offer comparable protections and concessions (e.g., rent relief, relocation assistance, community benefits agreements)
#   - Equity-centered outreach: targeted programs for renters, low-income neighborhoods, frontline workers; multilingual, culturally sensitive outreach
#   - Partnerships: collaborate with regional agencies, neighboring municipalities, universities for research support and grant writing; leverage philanthropic and corporate-sponsorship programs for public-good projects
#
# (g) Six most important uncertainties and low-cost, low-regret pilots to reduce them
# Top six uncertainties
# 1) Effectiveness and cost of nature-based solutions (living shorelines, marsh restoration)
# - Pilot: small-scale living shoreline trial (0.5–1 km) with rigorous monitoring (sediment dynamics, coastal ecology, performance metrics)
# - Cost: $1–3M; timeline: 2 years
# - Assumptions: will deliver measurable coastal protection benefits; results generalizable for larger scale
# - Failure modes: ecological factors underperform, maintenance costs higher than anticipated
# - Alternatives: conventional hard barriers only; add-on nature-based features later if necessary
#
# 2) Migration patterns and climate-induced displacement
# - Pilot: a housing mobility demonstration program in one neighborhood (rent subsidies, tenant protections, relocation assistance)
# - Cost: $5–8M over 3–4 years
# - Assumptions: targeted program will reduce displacement and stabilize housing markets
# - Failure modes: migration trends differ from projections; political constraints
# - Alternatives: broader regional coordination; expanded buyout program
#
# 3) Financing viability and leverage of external funds
# - Pilot: grant-writing and financing-structure pilot with a dedicated resilience fund officer
# - Cost: $0.5–1.0M; timeline: 1–2 years
# - Assumptions: grant success rates improve; political support for debt instruments
# - Failure modes: insufficient grants; refinancing risk
# - Alternatives: re-prioritize actions with higher grant potential; establish regional pooling
#
# 4) Microgrid performance and reliability
# - Pilot: microgrid test at one critical facility (hospital or water treatment plant)
# - Cost: $8–$12M
# - Assumptions: redundant power supply improves resilience; operational costs manageable
# - Failure modes: technology reliability challenges; interconnection issues
# - Alternatives: conventional backup generation; regional power-sharing agreements
#
# 5) Health impacts of heat and flood events under future climate
# - Pilot: community cooling centers and heat-health monitoring in one district
# - Cost: $0.5–1.0M
# - Assumptions: reduced hospitalizations through targeted cooling and health services
# - Failure modes: utilization rates low; weather patterns diverge from projections
# - Alternatives: broader cooling-center expansion; energy-efficiency incentives for homes
#
# 6) Equity safeguards effectiveness (anti-displacement policies)
# - Pilot: targeted renter protections and housing trust fund pilot with measurable displacement indicators
# - Cost: $2–4M over 3–4 years
# - Assumptions: protections reduce observed displacement
# - Failure modes: enforcement challenges; market pressure persists
# - Alternatives: more aggressive rent-control-like measures; regulatory changes
#
# Key assumptions and alternative strategies considered
# - Assumption: combined capital investments plus ongoing maintenance will yield long-term risk reductions and health benefits; alternative considered: delaying some actions or distributing costs differently across actions
# - Assumption: external funding will be available in a timely manner; alternative: increasing local debt or scaling back non-critical actions
# - Assumption: urban growth patterns remain stable; alternative: integrate growth management policies to align with resilience investments
# - Assumption: equity protections and relocation assistance are accepted by the community; alternative: more coercive policy approaches with greater political risk
#
# Notes on deliverables and risk management
# - The plan uses a phased approach with explicit triggers for re-prioritization based on new information (SLR measurements, hazard events, funding availability, housing-market conditions).
# - The financial plan emphasizes leveraging external funds, minimizing local tax impact, and ensuring protections for vulnerable groups are embedded in every major action.
# - The governance structure requires transparent reporting, inclusive governance, and credible measurement of equity outcomes.
#
# If you’d like, I can tailor the numbers above to your city’s exact risk exposure, coastline length, wastewater facility locations, and current tax base. I can also draft a one-page executive summary for Council briefing, plus a detailed implementation timeline and procurement plan.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# This plan outlines a comprehensive, equitable, and adaptive strategy for a mid-sized coastal city facing significant climate challenges. It prioritizes the protection of vulnerable populations, leverages multi-benefit solutions, and establishes a robust framework for long-term resilience under deep uncertainty.
#
# ---
#
# ### **City Climate Adaptation and Social Resilience Plan (2024-2044)**
#
# **Overall Vision:** To transform our city into a climate-resilient and equitable coastal community, safeguarding its residents, economy, and unique heritage from the escalating impacts of sea-level rise, storm surge, and a changing climate, while proactively integrating future populations.
#
# **Core Principles:**
# 1.  **Equity First:** Prioritize actions that disproportionately benefit the 30% of the population below median income and other vulnerable groups.
# 2.  **Multi-Benefit Solutions:** Favor interventions that offer co-benefits beyond climate adaptation (e.g., public health, green space, economic development).
# 3.  **Adaptive Governance:** Implement a flexible, learning-oriented approach that can adjust to new scientific information and changing conditions.
# 4.  **Economic Vitality:** Protect and enhance the city's economic engines, including the port and industry, through strategic partnerships.
# 5.  **Community-Led Resilience:** Ensure broad and inclusive stakeholder engagement throughout the planning and implementation process.
#
# ---
#
# **(a) Top 8 Actions: Justification, Estimated Costs, and Realistic Timelines**
#
# The following actions are prioritized to minimize total social cost while maximizing equity, utilizing the $500M budget over 10 years for a 20-year planning horizon.
#
# 1.  **Integrated Water Management & Green Infrastructure (IWM-GI) Program**
#     *   **Description:** A phased overhaul of aging combined sewer and wastewater infrastructure, significantly reducing combined sewer overflows (CSOs) and upgrading treatment plants for resilience. Concurrently, extensive deployment of green infrastructure (e.g., rain gardens, permeable streets, bioswales, urban wetlands) in flood-prone areas, especially in historic and low-income neighborhoods.
#     *   **Justification:** This addresses critical public health and environmental risks from aging infrastructure and chronic flooding. GI offers multiple co-benefits: improved water quality, reduced urban heat island effect, enhanced biodiversity, and expanded public green spaces, directly benefiting vulnerable communities. It's a foundational element of urban resilience.
#     *   **Estimated Total Cost (10 years):** $150 Million
#     *   **Realistic Timeline:** Phase 1 (urgent upgrades & pilot GI in highest-risk zones): Years 1-7. Phase 2 (broader GI, system optimization): Years 5-15. Ongoing maintenance and expansion.
#
# 2.  **Hybrid Coastal Protection & Restoration Initiative**
#     *   **Description:** A strategic blend of nature-based solutions (restoring coastal wetlands, oyster reefs, and dune systems) and targeted structural reinforcements (upgrading and elevating existing seawalls, levees, and flood barriers) around critical infrastructure (port, wastewater treatment plants) and sections of historic neighborhoods.
#     *   **Justification:** Nature-based solutions are cost-effective, adaptable, provide ecological co-benefits, and absorb wave energy. Targeted structural components are essential for robust protection of high-value assets. This hybrid approach offers flexibility under sea-level rise (SLR) uncertainty while maximizing environmental benefits.
#     *   **Estimated Total Cost (10 years):** $120 Million
#     *   **Realistic Timeline:** Initial restoration & critical structural upgrades: Years 1-8. Ongoing monitoring, adaptive reinforcement, and expansion: Years 5-20.
#
# 3.  **Vulnerable Communities Resilience & Equity Program (VCREP)**
#     *   **Description:** Provides financial assistance (grants/subsidies) for home elevation and flood-proofing, implements community-scale green infrastructure (e.g., cooling parks, tree planting) for heat mitigation, and establishes "Resilience Hubs" (community centers with emergency power, cooling, and resources) in low-income and historically marginalized neighborhoods.
#     *   **Justification:** Directly addresses equity by protecting the most vulnerable residents, who often lack resources for individual adaptation. It reduces flood and heat-related health risks, enhances livability, and builds essential social cohesion and emergency preparedness within communities.
#     *   **Estimated Total Cost (10 years):** $80 Million
#     *   **Realistic Timeline:** Program design & pilot implementation: Years 1-3. Phased deployment across vulnerable neighborhoods: Years 3-10. Ongoing support.
#
# 4.  **Strategic Land Use Planning & Managed Retreat Framework**
#     *   **Description:** Develops a comprehensive framework for identifying high-risk, un-defendable areas, coupled with a voluntary, equitable buyout and relocation program for residents and businesses. Includes updating zoning ordinances to restrict new development in floodplains and incentivize density in safe areas, and exploring land swaps for ecological restoration.
#     *   **Justification:** Proactive planning minimizes long-term social and economic costs by avoiding future development in harm's way and providing dignified pathways for those in areas facing insurmountable risk. Essential for long-term equity and adapting to higher SLR scenarios. This framework is crucial to avoid crisis-driven, inequitable displacement.
#     *   **Estimated Total Cost (10 years):** $40 Million (for framework development, regulatory updates, and initial pilot buyouts for ~150-200 properties)
#     *   **Realistic Timeline:** Framework development & regulatory updates: Years 1-4. Initial pilot buyouts and relocation support: Years 4-10. Ongoing as needed.
#
# 5.  **Climate Migration & Social Integration Strategy (CMSIS)**
#     *   **Description:** A proactive city-wide strategy to integrate future climate migrants, including: needs assessments for housing, services, and infrastructure; establishment of an affordable housing fund (leveraging external partners) in safe zones; job training and economic integration programs; and cultural support.
#     *   **Justification:** Climate migration will significantly impact the city. A proactive strategy ensures humane and economically beneficial integration, prevents social strain, ensures equitable access to resources for both new and existing residents, and harnesses new talent.
#     *   **Estimated Total Cost (10 years):** $20 Million
#     *   **Realistic Timeline:** Strategy development & initial assessments: Years 1-3. Program implementation & partnership building: Years 3-10.
#
# 6.  **Enhanced Early Warning & Emergency Response System (EWS-ERS)**
#     *   **Description:** Modernize flood and weather monitoring sensors, improve communication infrastructure (e.g., resilient fiber optics, backup power), develop hyper-local forecasting and public notification systems, and conduct extensive community education, drills, and evacuation planning. Harden critical emergency shelters and infrastructure.
#     *   **Justification:** A robust EWS-ERS is a fundamental "no-regret" action that saves lives, reduces immediate property damage, and builds public trust and preparedness across all climate scenarios.
#     *   **Estimated Total Cost (10 years):** $15 Million
#     *   **Realistic Timeline:** System upgrades & initial community rollout: Years 1-4. Ongoing maintenance, training, and drills.
#
# 7.  **Port & Industrial Sector Climate Partnership**
#     *   **Description:** Formal collaboration with the port authority and major industrial operators to conduct joint vulnerability assessments, co-develop adaptation strategies (e.g., elevated critical equipment, shared flood barriers, microgrids), and explore strategic relocation of highly exposed assets. The city provides technical assistance and regulatory alignment; industry leads implementation.
#     *   **Justification:** Protects the city's economic engine and major employment source. Proactive engagement prevents catastrophic failures, ensures supply chain resilience, leverages private sector investment, and mitigates potential environmental hazards during flooding.
#     *   **Estimated Total Cost (10 years):** $10 Million
#     *   **Realistic Timeline:** Partnership establishment & initial assessments: Years 1-3. Joint project planning & implementation: Years 3-10.
#
# 8.  **Adaptive Governance, Research & Development, & Monitoring (AGRDM)**
#     *   **Description:** Establish a dedicated Climate Resilience Office within city government, responsible for inter-agency coordination, ongoing vulnerability assessments, data collection, performance monitoring, public reporting, and regular plan updates (e.g., every 3-5 years). This office will also lead local R&D and pilot projects.
#     *   **Justification:** Provides the institutional backbone for sustained, evidence-based adaptation efforts. Ensures the plan remains dynamic, responsive to new climate information and socio-economic shifts, and accountable to the public. Critical for long-term effectiveness.
#     *   **Estimated Total Cost (10 years):** $15 Million
#     *   **Realistic Timeline:** Office establishment & initial staffing: Year 1. Ongoing operations, reporting, and plan updates.
#
# **Total Allocated Budget (10 years): $470 Million**
#
# ---
#
# **(b) Proposed Allocation of the $500M and Additional Funding Sources**
#
# **Allocation of $500M (over 10 years):**
# 1.  **IWM-GI Program:** $150 Million (30%)
# 2.  **Hybrid Coastal Protection:** $120 Million (24%)
# 3.  **VCREP:** $80 Million (16%)
# 4.  **Strategic Land Use & Managed Retreat:** $40 Million (8%)
# 5.  **CMSIS:** $20 Million (4%)
# 6.  **EWS-ERS:** $15 Million (3%)
# 7.  **Port & Industrial Sector Partnership:** $10 Million (2%)
# 8.  **AGRDM:** $15 Million (3%)
# *   **Contingency/Unallocated Buffer:** $30 Million (6%) – For unforeseen needs, pilot expansion, or leverage opportunities.
#
# **Justification for Allocation:** The allocation reflects a strategic balance:
# *   **Highest Priority (IWM-GI, Coastal Protection, VCREP):** These address fundamental physical vulnerabilities and directly support the equity mandate by protecting critical infrastructure and vulnerable populations.
# *   **Strategic Planning (Managed Retreat, Migration):** Smaller initial investments, but crucial for proactive, equitable, and cost-effective long-term adaptation.
# *   **Cross-Cutting & Enabling Actions (EWS-ERS, Port/Industry, AGRDM):** Essential for safety, economic stability, and the adaptive capacity of the entire plan.
#
# **Additional Funding Sources and Financing Mechanisms:**
# The $500M budget, while substantial, will require significant leveraging to meet the city's long-term adaptation needs.
#
# 1.  **Federal Grants & Programs:**
#     *   **Sources:** FEMA (BRIC, HMGP, FMA), EPA (CWSRF, DWSRF), HUD (CDBG-DR, National Coastal Resilience Fund), NOAA (Coastal Resilience Grants), IIJA funds.
#     *   **Expected Leverage Ratio:** 1:1 to 1:5 (City:Federal). The city's 30% low-income population helps qualify for higher federal cost shares.
#     *   **Political/Administrative Feasibility:** High potential but highly competitive and administratively intensive. Requires dedicated grant-writing capacity (funded by AGRDM).
#
# 2.  **State Grants & Bond Programs:**
#     *   **Sources:** State-level climate resilience funds, infrastructure bonds, matching grants for federal programs.
#     *   **Expected Leverage Ratio:** 1:0.5 to 1:2.
#     *   **Political/Administrative Feasibility:** Generally less competitive than federal, but depends on state political will and fiscal health.
#
# 3.  **Green Bonds/Resilience Bonds:**
#     *   **Mechanism:** Municipal bonds specifically for climate adaptation projects, appealing to ESG investors.
#     *   **Expected Leverage Ratio:** 1:5 to 1:10 (City's tax base supports debt service).
#     *   **Political/Administrative Feasibility:** High for cities with strong credit ratings; may require voter approval; good for large, predictable infrastructure costs.
#
# 4.  **Public-Private Partnerships (PPPs):**
#     *   **Mechanism:** Engage private sector for projects with revenue streams (e.g., port upgrades, mixed-use developments) or where private entities benefit directly (e.g., industrial sector adaptation).
#     *   **Expected Leverage Ratio:** 1:1 to 1:3 for specific projects.
#     *   **Political/Administrative Feasibility:** Complex negotiations; requires strong oversight to protect public interest.
#
# 5.  **Stormwater Utility Fee / Resilience Fee:**
#     *   **Mechanism:** Dedicated fee on property tax or utility bills, proportional to impervious surface, to fund IWM-GI and broader resilience.
#     *   **Expected Leverage Ratio:** Direct, dedicated revenue stream; can be used to back bonds.
#     *   **Political/Administrative Feasibility:** Can be politically challenging but provides a stable, local funding source. Requires strong public education.
#
# **Overall Funding Strategy:** A blended finance approach is essential. Municipal funds will serve as matching funds to unlock larger federal and state grants, resilience bonds will finance major infrastructure, and targeted PPPs will engage industry. A new stormwater/resilience fee will provide a consistent local revenue stream. The target leverage ratio over 20 years is at least 1:2 (municipal:external), aiming to unlock $1-1.5B in additional funding.
#
# ---
#
# **(c) Expected Outcomes by 20 Years (2044) under each Sea-Level Rise Scenario**
#
# **Assumptions & Methods for Outcome Estimates:**
# *   **Baseline (No Action):** Without this plan, annual flood damages (coastal & pluvial) are projected to increase by 100-200% by 2044 under the medium SLR scenario, along with worsening health outcomes and unplanned displacement.
# *   **Economic Damages Avoided:** Calculated as a percentage reduction in projected damages compared to the no-action baseline, based on protective capacity of implemented measures.
# *   **People Protected/Relocated:** "Protected" implies reduced risk, not elimination. "Relocated" refers to participants in voluntary buyout programs.
# *   **Health Outcomes Avoided:** Based on reduced exposure to flooding (fewer injuries, waterborne disease, mental health impacts) and reduced heat exposure (fewer heat-related illnesses/hospitalizations). Percentage reductions are used due to inherent variability.
# *   **Data Sources (Implicit):** Local flood maps, historic damage data, population density, property values, public health records, climate projections, engineering assessments.
# *   **Model Simplifications:** Assumes effective implementation and community cooperation. Does not account for all potential feedback loops or rare catastrophic events.
#
# **Scenario Details (2050 SLR):** Low = +0.5 m, Medium = +1.0 m, High = +1.5 m (used as proxies for risk levels by 2044).
#
# **Expected Outcomes by 2044:**
#
# **1. Low SLR Scenario (+0.5 m by 2050)**
#
# *   **Economic Damages Avoided:**
#     *   **Central Estimate:** 50% reduction in annual flood-related economic damages compared to baseline. (Range: 40-60%)
#     *   *Rationale:* Hybrid coastal protections and IWM-GI are highly effective against this level of SLR and associated storm surges. VCREP enhances individual property resilience.
# *   **Number of People Protected or Relocated:**
#     *   **Central Estimate:** 75,000 protected from chronic flooding/storm surge; 1,000 voluntarily relocated from highest-risk properties. (Range: 60,000-90,000 protected; 500-1,500 relocated).
#     *   *Rationale:* A large portion of the city is effectively protected. Managed retreat is targeted at the most critical, highest-risk properties.
# *   **Health Outcomes (Heat/Flood-related Hospitalizations Avoided):**
#     *   **Central Estimate:** 30% reduction in flood-related hospitalizations; 15% reduction in heat-related hospitalizations. (Range: 20-40% flood; 10-20% heat).
#     *   *Rationale:* Reduced flood exposure from IWM-GI and VCREP, along with urban cooling efforts, directly translate to better health. EWS-ERS contributes to immediate safety.
#
# **2. Medium SLR Scenario (+1.0 m by 2050)**
#
# *   **Economic Damages Avoided:**
#     *   **Central Estimate:** 35% reduction in annual flood-related economic damages compared to baseline. (Range: 25-45%)
#     *   *Rationale:* Defenses are more challenged, but still provide substantial protection. Higher water levels mean some areas become vulnerable more frequently. Managed retreat becomes more critical for sustained damage reduction.
# *   **Number of People Protected or Relocated:**
#     *   **Central Estimate:** 50,000 protected from chronic flooding/storm surge; 3,000 voluntarily relocated. (Range: 40,000-60,000 protected; 2,000-4,000 relocated).
#     *   *Rationale:* Some areas become too challenging to defend, shifting emphasis to managed retreat. The "protected" number is lower as some defenses are overtopped more frequently.
# *   **Health Outcomes (Heat/Flood-related Hospitalizations Avoided):**
#     *   **Central Estimate:** 20% reduction in flood-related hospitalizations; 10% reduction in heat-related hospitalizations. (Range: 15-30% flood; 5-15% heat).
#     *   *Rationale:* Increased flood frequency and depth reduce the overall effectiveness of some measures. Heat reduction remains beneficial but may be outpaced by overall warming.
#
# **3. High SLR Scenario (+1.5 m by 2050)**
#
# *   **Economic Damages Avoided:**
#     *   **Central Estimate:** 15% reduction in annual flood-related economic damages compared to baseline. (Range: 5-25%)
#     *   *Rationale:* This scenario presents extreme challenges. While foundational investments (IWM-GI, critical structural coastal protection) still offer some benefits, widespread inundation and frequent overtopping are expected. The primary "avoided damage" comes from proactive relocation and avoiding new development in hazard areas.
# *   **Number of People Protected or Relocated:**
#     *   **Central Estimate:** 20,000 protected from chronic flooding/storm surge; 10,000 voluntarily relocated. (Range: 10,000-30,000 protected; 8,000-12,000 relocated).
#     *   *Rationale:* Extensive areas are now considered un-defendable. The Managed Retreat Framework scales up significantly, becoming the dominant strategy for people in highly exposed areas.
# *   **Health Outcomes (Heat/Flood-related Hospitalizations Avoided):**
#     *   **Central Estimate:** 10% reduction in flood-related hospitalizations; 5% reduction in heat-related hospitalizations. (Range: 0-15% flood; 0-10% heat).
#     *   *Rationale:* The scale of flooding and heat stress means overall public health burden is high. Relocation becomes the most effective health intervention.
#
# **Summary:** The plan provides substantial protection under low and medium SLR scenarios, with benefits diminishing as SLR increases. Under a high SLR scenario, the plan's value shifts significantly towards proactive, equitable managed retreat and minimizing catastrophic losses through prepared planning, rather than attempting to hold all lines. Equity is consistently maximized by prioritizing vulnerable populations across all actions.
#
# ---
#
# **(d) Ethical and Distributive Trade-offs and Mitigation Measures**
#
# Implementing a climate adaptation plan of this scale inevitably involves ethical dilemmas and distributive trade-offs.
#
# **Main Ethical and Distributive Trade-offs:**
#
# 1.  **"Protect vs. Retreat":**
#     *   **Who Wins:** Properties and communities receiving large-scale structural or nature-based protection may see their property values retained or increased, and can maintain their current lifestyles.
#     *   **Who Loses:** Residents (especially low-income homeowners and renters) in areas identified for managed retreat may face displacement, loss of community ties, and potentially generational wealth, even with compensation. The emotional toll of leaving ancestral homes or familiar surroundings is significant.
#     *   **Short-term vs. Long-term:** Short-term protection of all areas might be politically popular but leads to much higher long-term social and economic costs. Retreat is disruptive in the short-term but offers long-term sustainability and reduced risk.
#
# 2.  **Funding Burden (General Taxpayer vs. Beneficiary Pays):**
#     *   **Who Wins:** General city residents benefit from a diversified funding approach that includes federal/state grants and bond financing, easing the burden on local property taxes.
#     *   **Who Loses:** If new dedicated fees (e.g., stormwater utility, resilience fee) are implemented, all property owners and potentially renters (through increased rents) will bear new costs. Small businesses may struggle with new fees or regulations.
#     *   **Short-term vs. Long-term:** Deferring local funding shifts costs to future generations or risks underfunding critical projects, leading to higher damages and costs later.
#
# 3.  **Industrial/Port Protection vs. Environmental Justice:**
#     *   **Who Wins:** The port and industrial sector, critical for the city's economy, are protected, ensuring jobs and revenue.
#     *   **Who Loses:** Communities surrounding industrial areas (often low-income and minority) may continue to bear disproportionate burdens from pollution or potential industrial accidents during storm events, even with some adaptation measures. Trade-offs on land use priorities (industrial growth vs. green space/housing) may arise.
#     *   **Short-term vs. Long-term:** Maintaining short-term economic stability could inadvertently prolong environmental injustices if not managed with explicit equity measures.
#
# 4.  **Preserving Historic Neighborhoods vs. Adaptation Costs/Effectiveness:**
#     *   **Who Wins:** Those who value the cultural and architectural heritage of specific neighborhoods.
#     *   **Who Loses:** Adaptation measures (e.g., elevating historic homes, constructing new flood barriers) can be prohibitively expensive, structurally complex, and alter aesthetics. If deemed unadaptable, these neighborhoods face degradation or loss.
#     *   **Short-term vs. Long-term:** Maintaining historic character in the short-term can incur higher maintenance costs and greater risk in the long-term if solutions are insufficient for accelerating SLR.
#
# 5.  **Focus on Current Residents vs. Climate Migrants:**
#     *   **Who Wins:** Existing residents might fear competition for resources and potential changes to community character if migration is poorly managed or unfunded.
#     *   **Who Loses:** Both current low-income residents (who might face displacement due to rising housing costs if affordable options aren't created) and climate migrants (who might face inadequate housing, services, and social friction) if integration isn't handled strategically and equitably.
#     *   **Short-term vs. Long-term:** Ignoring climate migration in the short-term will inevitably lead to overwhelming social costs, resource strain, and inequity in the long-term.
#
# **Concrete Policy Measures to Mitigate Harm and Ensure Fair Burden-Sharing:**
#
# 1.  **For "Protect vs. Retreat":**
#     *   **Equitable Buyout & Relocation Package:** Ensure buyouts are at pre-disaster fair market value (or higher, e.g., 120%), include compensation for moving expenses, job search assistance, and robust support for finding comparable, affordable housing in safe areas for both homeowners and renters.
#     *   **Community-Led Decision-Making:** Empower affected communities to co-design solutions, define "fair compensation," and choose relocation options through participatory processes.
#     *   **Land Trust Models:** Utilize community land trusts for acquired properties to prevent speculative development and preserve land for ecological restoration or community-defined uses.
#
# 2.  **For Funding Burden:**
#     *   **Progressive Fee Structures:** Design stormwater fees to be progressive, offering relief or exemptions for low-income households.
#     *   **Dedicated Resilience Fund Transparency:** Establish a transparent fund for all revenues and expenditures, clearly demonstrating how funds are protecting vulnerable populations and delivering benefits.
#     *   **Impact Fees on New Development:** Implement fees on new construction in low-risk zones to help fund infrastructure upgrades and resilience measures in existing areas.
#
# 3.  **For Industrial/Port Protection vs. Environmental Justice:**
#     *   **Mandatory Environmental & Social Impact Assessments:** Require rigorous assessments for any industrial adaptation project, including cumulative impacts on surrounding environmental justice communities.
#     *   **Community Benefit Agreements (CBAs):** Negotiate CBAs with port and industrial partners for projects, ensuring direct benefits (e.g., local job training, green infrastructure, community investment) flow to neighboring communities.
#     *   **"Polluter Pays" Principle:** Ensure that industry bears a significant portion of the cost for adapting their own facilities and mitigating their environmental impacts.
#
# 4.  **For Preserving Historic Neighborhoods:**
#     *   **Heritage Adaptation Fund:** Create a specific fund to subsidize the additional costs of flood-proofing and elevation methods that respect historic integrity, leveraging state and national preservation grants.
#     *   **Flexible Design Guidelines:** Develop clear guidelines for adaptation that prioritize historic character while ensuring structural resilience.
#
# 5.  **For Current Residents vs. Climate Migrants:**
#     *   **Affordable Housing Set-Asides:** Mandate a percentage of all new housing developed in safe zones, particularly through city incentives, be designated as affordable housing for both existing residents and future migrants.
#     *   **Inclusive Planning & Welcome Programs:** Ensure climate migrant representatives are included in planning discussions. Establish "welcome committees" and resource centers to facilitate social and economic integration.
#
# ---
#
# **(e) Monitoring Metrics and Adaptive Governance Rules**
#
# Adaptive governance is paramount for a 20-year plan facing deep uncertainty.
#
# **Compact Set of 6 Measurable Monitoring Metrics (with targets for 2044):**
#
# 1.  **Flood Inundation & Recurrence (Effectiveness of IWM-GI & Coastal Protection):**
#     *   **Metric:** Annual number of properties and total acreage experiencing nuisance or damaging flood events (>0.15m depth), differentiated by flood type (coastal, pluvial).
#     *   **Target (2044 vs. 2024 baseline):** 25% reduction under Low SLR; maintain 2024 levels under Medium SLR; limit expansion to 50% increase under High SLR.
#     *   **Trigger:** If annual flood events exceed the 2024 baseline by >10% for 3 consecutive years (Medium SLR scenario) OR flood events exceed the 2024 baseline by >50% for 2 consecutive years (High SLR scenario).
#         *   **Contingent Action:** Re-evaluate all relevant protection projects, accelerate managed retreat efforts, reallocate funds to more robust solutions.
#
# 2.  **Vulnerable Population Protection & Equity (VCREP & Managed Retreat):**
#     *   **Metric:** Percentage of properties in identified vulnerable neighborhoods (30% below median income) that have implemented flood-proofing/elevation, or have access to a Resilience Hub within 1 mile. Also, percentage of managed retreat participants reporting satisfactory relocation outcomes.
#     *   **Target (2044):** 70% of identified vulnerable properties adapted/served; 90% satisfaction rate for retreat participants.
#     *   **Trigger:** If progress on vulnerable property adaptation is <50% of the 5-year target, OR if satisfaction rate for retreat participants falls below 75%.
#         *   **Contingent Action:** Immediately review and revise VCREP incentives/outreach; re-evaluate buyout packages and relocation assistance; establish independent ombudsman.
#
# 3.  **Coastal Ecosystem Health & Resilience (Hybrid Coastal Protection):**
#     *   **Metric:** Acreage of established and ecologically functional restored coastal wetlands and dunes; measured wave height attenuation during specific storm events.
#     *   **Target (2044):** 1,000 acres of restored wetlands/dunes; 10% average wave height attenuation in protected areas.
#     *   **Trigger:** If >20% of restored areas show significant degradation after a major storm, or if expected wave attenuation is not observed after 5 years of project maturity.
#         *   **Contingent Action:** Investigate causes of degradation; adjust restoration techniques; re-evaluate reliance on NBS in specific areas; consider targeted structural reinforcements.
#
# 4.  **Climate Migration & Housing Capacity (CMSIS):**
#     *   **Metric:** Percentage increase in affordable housing units in designated safe zones; average occupancy rate of emergency shelters.
#     *   **Target (2044):** 20% increase in affordable housing units; maintain <80% average occupancy rate in emergency shelters.
#     *   **Trigger:** If affordable housing construction lags by >25% of 5-year targets, OR if emergency shelter occupancy consistently exceeds 90% for 6 months.
#         *   **Contingent Action:** Fast-track affordable housing development; launch emergency housing initiatives; update migration projections and infrastructure plans.
#
# 5.  **Public Health Outcomes (Overall Plan Impact):**
#     *   **Metric:** Number of heat-related hospitalizations (adjusted for population growth); number of waterborne disease outbreaks linked to infrastructure failure.
#     *   **Target (2044):** 20% reduction in heat-related hospitalizations; Zero waterborne disease outbreaks related to infrastructure failure.
#     *   **Trigger:** If heat-related hospitalizations increase for 2 consecutive summers, OR if any waterborne disease outbreak is linked to CSOs/WWTPs.
#         *   **Contingent Action:** Expand heat mitigation efforts (e.g., cooling centers, tree canopy); reallocate funds to IWM-GI; launch public health emergency campaigns.
#
# 6.  **Financial Sustainability & External Funding (Overall Plan Management):**
#     *   **Metric:** Ratio of external (federal/state/private) funding leveraged to municipal adaptation spending.
#     *   **Target (2044):** Maintain a leverage ratio of at least 1:2.
#     *   **Trigger:** If the leverage ratio falls below 1:1.5 for 2 consecutive years, AND the contingency budget is depleted to less than $10M.
#         *   **Contingent Action:** Initiate public dialogue for a dedicated local resilience tax/fee; re-prioritize only "no-regret" or high-ROI projects; pause or scale back less critical elements of the plan.
#
# ---
#
# **(f) Politically Pragmatic Stakeholder Engagement and Communication Strategy**
#
# Building durable cross-party consent in a polarized context requires transparency, common ground, and tailored messaging.
#
# **Core Principles:** Trust, Benefit Framing, Empowerment, Fairness, and Accountability.
#
# **Strategy Components:**
#
# 1.  **Establish a Diverse Resilient City Commission:**
#     *   **Composition:** Representatives from business (Chamber of Commerce, Port Authority), industry, labor unions, environmental groups, neighborhood associations (including low-income and historic districts), academic experts, faith leaders, and elected officials from across the political spectrum.
#     *   **Role:** Serve as a transparent, independent body to oversee plan implementation, provide ongoing input, resolve disputes, and act as a consensus-building forum. This can depoliticize specific adaptation decisions.
#     *   **Communication:** Regular public meetings (livestreamed), comprehensive online dashboard showing progress, successes, and challenges, and an annual "State of Resilience" report.
#
# 2.  **Tailored Messaging and Communication Channels:**
#
#     *   **General Public:**
#         *   **Message:** "Safe Homes, Strong Economy, Healthy Communities." Focus on tangible benefits: reduced flooding in neighborhoods, cleaner water, cooler streets, protection of jobs and local businesses. Emphasize multi-generational security.
#         *   **Channels:** Community town halls (translated), local news partnerships (radio, TV, print), social media campaigns (visual stories, FAQs), dedicated city resilience website, "resilience fairs."
#         *   **Approach:** Start with "no-regret" actions that have immediate, visible benefits (e.g., improved drainage, new cooling parks).
#
#     *   **Industry (Port & Heavy Industry):**
#         *   **Message:** "Business Continuity, Economic Competitiveness, Shared Responsibility." Frame adaptation as a strategic investment in supply chain resilience, protecting assets, and maintaining market competitiveness. Highlight collaborative opportunities for shared infrastructure and risk reduction.
#         *   **Channels:** Direct meetings with C-suite executives, industry roundtables, Chamber of Commerce, workshops on risk assessment and funding opportunities.
#         *   **Approach:** Present clear financial analyses (ROI on avoided losses). Offer technical assistance and help navigating complex grants. Emphasize regulatory predictability and partnership.
#
#     *   **Renters (especially Low-Income):**
#         *   **Message:** "Stable, Affordable Homes in Safe Neighborhoods." Focus on tenant protections during adaptation, affordable housing development in safe zones, and direct flood/heat relief for their living spaces. Guarantee relocation assistance and fair treatment if retreat is necessary.
#         *   **Channels:** Partner with tenant associations, community organizers, social service agencies, and legal aid groups. Culturally and linguistically appropriate outreach in vulnerable neighborhoods.
#         *   **Approach:** Build trust through direct engagement and visible, equitable outcomes. Highlight VCREP and CMSIS benefits directly relevant to their security and well-being.
#
#     *   **Fiscally Conservative Groups:**
#         *   **Message:** "Smart Investment, Fiscal Responsibility, Long-Term Savings." Frame adaptation as proactive risk management that avoids much higher future costs (disaster relief, insurance claims, economic disruption). Emphasize leveraging external funds (federal, state, private) and efficient use of taxpayer money.
#         *   **Channels:** Taxpayer associations, business councils, editorial boards, one-on-one meetings with elected officials.
#         *   **Approach:** Present robust cost-benefit analyses, showing the return on investment for adaptation. Highlight accountability mechanisms (AGRDM) and the need to plan prudently for the future.
#
# **Handling Opposition:**
#
# *   **Empathy and Active Listening:** Never dismiss concerns. Understand the underlying fears (e.g., "tax hike" vs. "cost of inaction," "property rights" vs. "public safety," "loss of community").
# *   **Data-Driven Dialogue:** Use clear, localized data and projections to explain risks and benefits. Employ independent experts to validate information and build credibility.
# *   **Finding Common Ground:** Identify shared values (e.g., economic stability, children's future, community pride) and frame solutions around them. Offer flexible solutions where possible without compromising core goals.
# *   **Transparency & Accountability:** Be open about challenges and trade-offs. Show how funds are being spent and what results are being achieved.
# *   **Showcase Early Wins:** Publicize successful projects quickly – a newly greened park, a successful grant award, a neighborhood protected from flooding.
# *   **Legal & Regulatory Clarity:** Ensure that all actions are backed by a strong, clear, and fair legal framework to minimize disputes and provide certainty.
#
# ---
#
# **(g) Six Most Important Scientific, Economic, or Social Uncertainties & Low-Cost Pilots**
#
# Deep uncertainty requires an adaptive approach. Here are the most critical uncertainties driving this plan, along with low-cost, low-regret pilot projects to reduce them.
#
# 1.  **Uncertainty: Rate and Extent of Local Sea-Level Rise (SLR) and Storm Intensification.**
#     *   **Impact:** Directly influences the effectiveness, design specifications, and lifespan of coastal protection measures and the scale/urgency of managed retreat.
#     *   **Low-Cost Pilot:** **Enhanced Local Tide Gauge Network & High-Resolution Topography/Bathymetry Mapping.**
#         *   **Description:** Install several new, real-time tide gauges strategically along the city's coastline. Conduct updated high-resolution LiDAR and bathymetric surveys to identify localized "hot spots" of vulnerability and potential subsidence. Integrate data into a publicly accessible dashboard.
#         *   **Estimated Cost:** $1.5 Million (equipment, installation, 5 years data processing/analysis).
#         *   **Timeline:** 1-2 years for installation, ongoing monitoring.
#         *   **Assumptions:** Data quality is high, allows for localized projections that refine regional models.
#         *   **Failure Modes:** Equipment malfunction, lack of sustained funding for analysis, data not adequately integrated into planning.
#         *   **Alternative Strategies:** Rely solely on regional projections (higher local uncertainty); over-engineer all defenses (prohibitively expensive, potential mal-adaptation).
#
# 2.  **Uncertainty: Future Magnitude and Spatial Distribution of Climate Migration to the City.**
#     *   **Impact:** Crucially affects demand for housing, public services, infrastructure capacity, and social integration. Misjudging this could lead to resource strain or social friction.
#     *   **Low-Cost Pilot:** **Regional Climate Migration Forecasting & Scenario Planning.**
#         *   **Description:** Partner with academic institutions and neighboring municipalities/counties (both coastal and inland source regions) to develop localized migration models. Host stakeholder workshops to co-create plausible migration scenarios and associated demand profiles for housing, jobs, and services.
#         *   **Estimated Cost:** $0.75 Million (consultants, academic partnerships, workshop logistics, data sharing platforms).
#         *   **Timeline:** 1-2 years.
#         *   **Assumptions:** Regional data is available, participation from diverse stakeholders is high.
#         *   **Failure Modes:** Lack of regional cooperation; models prove inaccurate; political unwillingness to acknowledge migration implications.
#         *   **Alternative Strategies:** Assume a fixed population growth rate (ignoring migration dynamics); build excess capacity everywhere (inefficient).
#
# 3.  **Uncertainty: Effectiveness and Longevity of Nature-Based Solutions (NBS) in a Dynamic Coastal Environment.**
#     *   **Impact:** Affects investment decisions for hybrid coastal protection and the long-term reliability of these systems, especially in the face of extreme events.
#     *   **Low-Cost Pilot:** **Multi-Site Living Shoreline/Wetland Restoration Experiment.**
#         *   **Description:** Implement 2-3 small-scale (e.g., 1-acre) living shoreline/wetland restoration projects in different coastal settings (e.g., exposed vs. sheltered). Monitor their ecological health, sediment accretion, wave attenuation capacity, and resilience during storm events, comparing performance to any nearby hardened structures.
#         *   **Estimated Cost:** $2 Million (for small-scale restoration, instrumentation, 5 years monitoring).
#         *   **Timeline:** 2-5 years for establishment, 5+ years for monitoring.
#         *   **Assumptions:** Projects can be adequately scaled if successful; monitoring technology is reliable.
#         *   **Failure Modes:** Pilot sites fail prematurely due to unexpected storms or pollution; monitoring data is inconclusive.
#         *   **Alternative Strategies:** Fully commit to NBS without local data (risky); exclusively rely on traditional hard structures (misses co-benefits, less adaptable).
#
# 4.  **Uncertainty: Socio-Economic Impacts and Community Acceptance of Managed Retreat.**
#     *   **Impact:** Directly influences the political feasibility, speed, and equity outcomes of the managed retreat framework. Strong community resistance can lead to plan stagnation or inequitable outcomes.
#     *   **Low-Cost Pilot:** **Community-Led Retreat Visioning & Compensation Design Pilot.**
#         *   **Description:** Work with one small, highly vulnerable, low-income neighborhood. Facilitate intensive, paid community workshops to understand their priorities, fears, and design principles for fair compensation and relocation assistance. Develop a detailed, voluntary "mock" buyout/relocation plan based on their input.
#         *   **Estimated Cost:** $0.5 Million (facilitation, community stipends, legal advice, planning expertise).
#         *   **Timeline:** 1-2 years.
#         *   **Assumptions:** Community members are willing to engage; insights are generalizable to other neighborhoods.
#         *   **Failure Modes:** Community resistance to the concept itself; inability to reach consensus; pilot results not politically actionable.
#         *   **Alternative Strategies:** Implement a top-down buyout program (likely to fail or be inequitable); delay retreat until a crisis (much higher social and economic cost).
#
# 5.  **Uncertainty: Economic Viability and Private Sector Engagement in Adaptation.**
#     *   **Impact:** Determines the success of the Port & Industrial Sector Climate Partnership and the overall leverage of private capital for resilience. What incentives are truly needed for industry to invest?
#     *   **Low-Cost Pilot:** **Industrial Resilience Accelerator Program.**
#         *   **Description:** Launch a small accelerator program providing matching grants (e.g., $50k-$200k) and technical assistance to 3-5 small-to-medium sized businesses in the industrial zone to implement climate resilience measures (e.g., elevating critical equipment, backup power, water storage). Track ROI and business continuity benefits.
#         *   **Estimated Cost:** $1 Million (grants, technical assistance, program management).
#         *   **Timeline:** 2-3 years.
#         *   **Assumptions:** Businesses are willing to participate; measurable benefits can be demonstrated.
#         *   **Failure Modes:** No businesses apply; pilot projects fail; data on ROI is not compelling for broader adoption.
#         *   **Alternative Strategies:** Mandate industry adaptation (high political resistance); provide no incentives (low adoption).
#
# 6.  **Uncertainty: Long-term Effectiveness and Maintenance Costs of Green Infrastructure (GI).**
#     *   **Impact:** Influences the sustainability of IWM-GI investments and future municipal budget allocations for operations and maintenance, ensuring GI delivers on its promised benefits.
#     *   **Low-Cost Pilot:** **Neighborhood Green Infrastructure Monitoring & Participatory Maintenance Cohort.**
#         *   **Description:** Select 3-5 diverse GI projects (e.g., rain gardens, permeable streets) in different neighborhoods. Engage community groups in participatory monitoring (citizen science for performance tracking) and hands-on maintenance. Track performance (e.g., stormwater capture, runoff reduction) and collect detailed data on actual maintenance needs and costs.
#         *   **Estimated Cost:** $0.5 Million (equipment, community training, staff oversight, 5 years monitoring).
#         *   **Timeline:** 2-5 years.
#         *   **Assumptions:** Community involvement is sustainable; monitoring data is accurate.
#         *   **Failure Modes:** Community engagement wanes; GI projects fail due to poor design or unexpected conditions; maintenance costs are higher than anticipated.
#         *   **Alternative Strategies:** Implement GI without robust monitoring (risk of ineffective investments); rely solely on professional maintenance (higher cost, less community ownership).
#
# These pilots, collectively costing $6.75M within the initial 10-year budget, are designed to generate actionable insights within the planning horizon, allowing for adaptive adjustments that will significantly reduce overall social costs and enhance the equity outcomes of the larger plan.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[9], line 6
#       3 groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
#       4 model_name = "openai/gpt-oss-120b"
# ----> 6 response = groq.chat.completions.create(model=model_name, messages=messages)
#       7 answer = response.choices[0].message.content
#       9 display(Markdown(answer))
#
# File c:\Users\Andreu Ortega Blasi\projects\agents\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\Andreu Ortega Blasi\projects\agents\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File c:\Users\Andreu Ortega Blasi\projects\agents\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Andreu Ortega Blasi\projects\agents\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'message': 'Access denied. Please check your network settings.'}}

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
