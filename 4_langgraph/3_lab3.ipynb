# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ## Extra installation step - if you don't have Node and Playwright on your computer
#
# Next, you need to install NodeJS and Playwright on your computer if you don't already have them. Please see instructions here:
#
# [Node and Playwright setup](../setup/SETUP-node.md)

# %% [markdown]
# ## And now - after Installing Playwright, a heads up for Windows PC Users:
#
# While executing the next few cells, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky! You need to do this AFTER installing Playwright (prior cells)
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out the entire else clause that this line is a part of - see the fragment below. Be sure to have the "pass" statement after the ImportError line.
# 5. Restart the kernel by pressing the "Restart" button above
#
# ```python
#         if sys.platform.startswith("win") and sys.version_info >= (3, 8):
#             import asyncio
#
#             try:
#                 from asyncio import WindowsProactorEventLoopPolicy, WindowsSelectorEventLoopPolicy
#             except ImportError:
#                 pass
#                 # not affected
#            # else:
#             #    if type(asyncio.get_event_loop_policy()) is WindowsProactorEventLoopPolicy:
#                     # WindowsProactorEventLoopPolicy is not compatible with tornado 6
#                     # fallback to the pre-3.8 default of Selector
#                     # asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())
# ```
#
# Thank you to student Nicolas for finding this, and to Kalyan, Yaki, Zibin and Bhaskar for confirming that this worked for them! And to Vladislav for the extra pointers.
#
# As an alternative, you can just move to a Python module (which we do anyway in Day 5)

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# If you get a NotImplementedError here or later, see the Heads Up at the top of the notebook

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\Andreu Ortega Blasi\AppData\Local\ms-playwright\chromium-1187\chrome-win\chrome.exe> version=140.0.7339.16>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\Andreu Ortega Blasi\AppData\Local\ms-playwright\chromium-1187\chrome-win\chrome.exe> version=140.0.7339.16>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\Andreu Ortega Blasi\AppData\Local\ms-playwright\chromium-1187\chrome-win\chrome.exe> version=140.0.7339.16>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\Andreu Ortega Blasi\AppData\Local\ms-playwright\chromium-1187\chrome-win\chrome.exe> version=140.0.7339.16>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\Andreu Ortega Blasi\AppData\Local\ms-playwright\chromium-1187\chrome-win\chrome.exe> version=140.0.7339.16>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\Andreu Ortega Blasi\AppData\Local\ms-playwright\chromium-1187\chrome-win\chrome.exe> version=140.0.7339.16>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\Andreu Ortega Blasi\AppData\Local\ms-playwright\chromium-1187\chrome-win\chrome.exe> version=140.0.7339.16>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.coinarchives.com/a/results.php?search=indo&s=0&upcoming=0&results=100"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# CoinArchives.com Search Results : indo Ancient Coins World Coins
# Search options ► Search mode: Simple Boolean (AND/NOT) Your search for
# 'indo ' matched 316 lots from auctions added in the last six months.
# Only the first 100 results are shown. To search our full database of
# over 10 million records, please subscribe to CoinArchives Pro . Search
# for 'indo' in upcoming auctions at Auction Date Price Realized Harlan
# J. Berk, Ltd. - Buy or Bid Sale 235, Lot 143 Indo-Parthia, Abdagases
# I. Tetradrachm; Indo-Parthia, Abdagases I; ca. 55-65 AD, Tetradrachm,
# 8.58g. S-227, Mitchiner-1117c. Obv: ΒΑCΙΛΕV ΑΠΑ VΝΔΙΦΕΡΟ ΑΔΕΛΦΙΔΕWΣ,
# King riding to r, dinastic monogram r. Rx: Zeus with long scepter,
# raising hand; Monogram and symbols flanking, same legend but in
# karoshti around. Ex Prof. David MacDonald collection.Dark toning. EF
# Estimate: 120 USD... 14 May 2026 Upcoming Auction Harlan J. Berk, Ltd.
# - Buy or Bid Sale 235, Lot 149 Bactria, Hermaeus. Drachm; Bactria,
# Hermaeus; Posthumous issue struck by Indo-Skythians, uncertain mint in
# the Paropamisadai, ca. 55-50 BC, Drachm, 2.33g. Bopearachchi-13B,
# HGC-12 303. Obv: BAΣIΛEΩΣ ΣΩTHPOΣ - EPMAIOY, Diad and dr bust r. Rx:
# Zeus std slightly l, raising hand and holding scepter; to l, monogram.
# Ex Prof. David MacDonald collection.. toned virtually ms  Estimate:
# 200 USD... 14 May 2026 Upcoming Auction Harlan J. Berk, Ltd. - Buy or
# Bid Sale 235, Lot 150 Bactria, Hermaeus. Drachm; Bactria, Hermaeus;
# Posthumous issue struck by Indo-Skythians near Kabul, ca. 50-35 BC,
# Drachm, 1.85g. Senior-Hermaios 38aD.1, Bop-17b, HGC-12 305. Obv:
# BAΣIΛEΩΣ ΣΩTHPOΣ EPMAIOY, Diad and dr bust r. Rx: Zeus std slightly l,
# raising hand and holding scepter; monogram to l.. EF  Estimate: 150
# USD... 14 May 2026 Upcoming Auction Harlan J. Berk, Ltd. - Buy or Bid
# Sale 235, Lot 153 Anonymous Indo-Scythian. Hemidrachm; Anonymous Indo-
# Scythian; ca. 110-100 BC, Hemidrachm, 0.73g. Cf. Mitchiner-2142-46.
# Obv: Horse walking r, head turned back. Rx: Winged Nike r. Ex Prof.
# David MacDonald collection.. VF  Estimate: 175 USD... 14 May 2026
# Upcoming Auction Dr. Busso Peus Nachfolger - Auction 445, Lot 1517
# Indien Saka Könige (Indoskythen) Vonones, 100-65 v. Chr., und
# Spalagadames Tetradrachme, unbest. Mzst. im westlichen Gandhara. König
# mit Lanze zu Pferd / Zeus-Helios mit Blitz und Zepter, rechts
# Monogramm. 12h.  Mitchiner VI, 681b; HGC 609. 9.77 g.; 23,9 mm. Zarte
# Tönung Selten Fast vorzüglich Aus der Sammlung eines Lehrers für alte
# Sprachen. Erworben im Dezember 1996 bei Cummings, Grantham (Nr. 170
# der Verkaufsliste).  Estimate: 200 EUR... 22 Apr 2026 Upcoming Auction
# Dr. Busso Peus Nachfolger - Auction 445, Lot 1518 Indien Saka Könige
# (Indoskythen) Maues, 90-57 v. Chr. Tetradrachme, Taxila. Zeus mit
# Zepter / Nike mit Palmwedel und Kranz. 2h.  Mitchiner V, 729a; HGC
# 524. 9.66 g.; 28,7 mm. Zarte Tönung Sehr schön Aus der Sammlung eines
# Lehrers für alte Sprachen. Erworben im Dezember 1996 bei Cummings,
# Grantham (Nr. 169 der Verkaufsliste).  Estimate: 100 EUR... 22 Apr
# 2026 Upcoming Auction Dr. Busso Peus Nachfolger - Auction 445, Lot
# 1519 Indien Saka Könige (Indoskythen) Azilises, 57-35 v. Chr.
# Tetradrachme, unbest. Mzst. König mit Lanze reitend / Göttin mit
# Fruchtschale und Palmzweig. 12h.  Mitchiner 801p; HGC 568. 9.68 g.;
# 25,6 mm. Feine Tönung Fast vorzüglich Aus der Sammlung eines Lehrers
# für alte Sprachen. Erworben im Mai 1997 bei Cummings, Grantham (Nr.
# G166 der Verkaufsliste).  Estimate: 150 EUR... 22 Apr 2026 Upcoming
# Auction Dr. Busso Peus Nachfolger - Auction 445, Lot 1520 Indien Saka
# Könige (Indoskythen) Azes II., 35-5 v. Chr. Tetradrachme, Taxila
# Sirsukh. König zu Pferd / Athena nach rechts zwischen 2 Monogrammen.
# 12h. Dazu: Drachme des Hermaios Soter und Bronze Azes' I.  Mitchiner
# VI, S. 542, Typ 848d.8; HGC 637. 3 Stück 9.57 g.; 24 mm. Feine Tönung
# Vorzüglich  Estimate: 175 EUR... 22 Apr 2026 Upcoming Auction
# Classical Numismatic Group - Electronic Auction 607, Lot 364 BAKTRIA,
# Indo-Greek Kingdom. Menander I Soter. Circa 155-130 BC. AR Drachm
# (17.5mm, 2.39 g, 12h). Diademed, draped, and cuirassed bust right,
# wearing crested helmet covered with pelt of scales and adorned with
# wing / Athena Alkidemos advancing left; monogram to right.
# Bopearachchi 16C; SNG ANS 855-65; HGC 12, 193. Deeoly toned with
# traces of iridescence, deposits. VF.   From the Colin E. Pitchfork
# Collection.    Estimate: 100 USD... 15 Apr 2026 Upcoming Auction
# Classical Numismatic Group - Electronic Auction 607, Lot 365 BAKTRIA,
# Indo-Greek Kingdom. Amyntas Nikator. Circa 80-65 BC. Æ (22x24.5mm,
# 7.42 g, 12h). Square module. Radiate bust of Zeus-Mithra right,
# wearing Phrygian cap / Athena standing left, raising right hand in
# benediction, holding spear and shield in left; monogram to lower left.
# Bopearachchi 15A; HGC 14, 428. Dark brown surfaces. VF. Very rare.
# Estimate: 100 USD... 15 Apr 2026 Upcoming Auction Classical Numismatic
# Group - Electronic Auction 607, Lot 366 BAKTRIA, Indo-Greek Kingdom.
# Zoilos II Soter. Circa 65-55 BC. Æ (14mm, 3.93 g, 12h). Round module.
# Elephant standing right / Tripod; mi? in Kharosthi to left; bha? in
# Kharosthi to right. Bopearachchi Série 8 (monograms unlisted); SNG ANS
# –; HGC 12, 471; Zeno –. Rough earthen green patina. Good Fine. Very
# rare.     Estimate: 100 USD... 15 Apr 2026 Upcoming Auction Classical
# Numismatic Group - Electronic Auction 607, Lot 367 BAKTRIA, Indo-Greek
# Kingdom. Zoilos II Soter. Circa 65-55 BC. Æ (28x27mm, 12.63 g, 12h).
# Square module. Apollo standing right, with quiver on back, holding
# arrow; monogram to left / Tripod; ra in Kharosthi to left, di in
# Kharosthi to right. Bopearachchi –; Bopearachchi & Rahman –; SNG ANS
# –; Zeno  –; HGC 12 –; CNG E-558, lot 264. Dark green and brown patina,
# heavy cleaning marks. Good Fine. Very rare.     Estimate: 150 USD...
# 15 Apr 2026 Upcoming Auction Classical Numismatic Group - Electronic
# Auction 607, Lot 368 BAKTRIA, Indo-Greek Kingdom. Dionysios Soter.
# Circa 55-45 BC. Æ (14x14mm, 3.72 g, 12h). Square module. Apollo
# standing right, with quiver on back, holding arrow / Diadem.
# Bopearachchi 4A; SNG ANS 1653; HGC 12, 463. Dark brown patina, areas
# of stable green, some cleaning marks. VF. Very rare.     Estimate: 100
# USD... 15 Apr 2026 Upcoming Auction Classical Numismatic Group -
# Electronic Auction 607, Lot 369 BAKTRIA, Indo-Greek Kingdom. Strato II
# Soter. Circa 25 BC-AD 10. Æ (20mm, 8.16 g, 12h). Round module. Joint
# issue with Strato III Philopator. Apollo standing right, holding arrow
# / Tripod; am in Kharosthi to left; na in Kharosthi to right. Cf.
# Bopearachchi 7C and pl. 69, V-X; ; Senior, Chakwal Hoard, –, but cf.
# 107; SNG ANS –; HGC 12, 487. Earthen brown and green patina, cleaning
# marks. Fine.     Estimate: 100 USD... 15 Apr 2026 Upcoming Auction
# Classical Numismatic Group - Electronic Auction 607, Lot 370 INDO-
# PARTHIANS, Margiana or Sogdiana. Uncertain. Late 1st century BC-early
# 1st century AD. AR Drachm (19mm, 3.07 g, 12h). "Helmeted" Countermark
# issue. Imitating countermarked drachms of Parthian king Phraates IV.
# Diademed and draped bust left; behind, eagle left, holding wreath; on
# neck, circular "countermark" of helmeted king right / Archer (Arsakes
# I) seated right on throne, holding bow. Senior 199.2D; Sellwood 91.13;
# Sunrise 494. Lightly toned, porous. Good VF.     Estimate: 150 USD...
# 15 Apr 2026 Upcoming Auction Classical Numismatic Group - Electronic
# Auction 607, Lot 371 INDO-SKYTHIANS. Maues. Circa 125-85 BC. AR
# Tetradrachm (26mm, 9.76 g, 11h). Zeus standing left, holding torque in
# extended right hand and cradling scepter in left arm / Nike standing
# right, holding wreath in extended right hand and filleted palm frond
# over left shoulder; monogram to inner right. Senior 1.1T; HGC 12, 524.
# Good VF.   From the Colin E. Pitchfork Collection. Ex Classical
# Numismatic Group Electronic Auction 237 (21 July 2010), lot 60.
# Estimate: 150 USD... 15 Apr 2026 Upcoming Auction Classical Numismatic
# Group - Electronic Auction 607, Lot 372 INDO-SKYTHIANS. Azilises.
# Circa 85-45/35 BC. AR Tetradrachm (28mm, 9.77 g, 12h). King on
# horseback right, holding spear / Athena Alkidemos left; monogram to
# left, a in Kharosthi to right. / Athena Alkidemos left; monogram to
# left, a in Kharosthi to right. Senior 65.1T; HGC 12, 609. Toned, areas
# of hard green. Good VF.   From the Colin E. Pitchfork Collection.
# Estimate: 100 USD... 15 Apr 2026 Upcoming Auction Classical Numismatic
# Group - Electronic Auction 607, Lot 373 INDO-SKYTHIANS. Azes. Circa
# 58-12 BC. AR Tetradrachm (28mm, 9.52 g, 12h). Azes on horseback right,
# holding spear; ra in exergue / Zeus standing facing, holding
# thunderbolt and scepter; monogram to left; a in Kharosthi to right.
# Senior 88.3T; HGC 12, 626. Lightly toned, light porosity. VF.   From
# the Colin E. Pitchfork Collection. Ex Classical Numismatic Group
# Electronic Auction 297 (27 February 2013), lot.    Estimate: 150
# USD... 15 Apr 2026 Upcoming Auction Classical Numismatic Group -
# Electronic Auction 607, Lot 374 INDO-SKYTHIANS. Azes. Circa 58-12 BC.
# AR Drachm (16mm, 1.92 g, 12h). King on horseback right, holding whip;
# ka in Kharosthi to right / Athena standing right, extending right hand
# and holding spear and shield; monograms to left and right. Senior
# 98.112D; HGC 12, 653. Toned, areas of find patina/deposits. VF.   From
# the Colin E. Pitchfork Collection. Ex Christie's New York (5 June
# 1991), lot 102 (part of).    Estimate: 100 USD... 15 Apr 2026 Upcoming
# Auction Need access to more market information? Research tools for
# professionals CoinsNB - E-Auction 55, Lot 173 India (ancient) Indo-
# Greek Kingdom 125 BC - 110 BC AE - Philoxenos Aniketos (Helios & Nike)
# Bronze 8.21g VF Bopearachchi 12A HGC 12, 276  Estimate: 100 EUR
# Starting price: 1 EUR... 26 Mar 2026 20 EUR CoinsNB - E-Auction 55,
# Lot 174 India (ancient) Indo-Scythian Kingdom 35 BC - 12 BC AE
# Pentachalkon - Azes II Copper 11.6g VF  Estimate: 50 EUR  Starting
# price: 1 EUR... 26 Mar 2026 22 EUR CoinsNB - E-Auction 55, Lot 177
# India (ancient) Western Satraps Indo-Scythian Kingdom - Ksahtrap
# Dynasty 255 - 278 AR Drachm - Rudrasena II (Brockage Type) Rare Silver
# 2.43g XF  Estimate: 200 EUR  Starting price: 1 EUR... 26 Mar 2026
# 36 EUR CoinsNB - E-Auction 55, Lot 178 India (ancient) Western Satraps
# Indo-Scythian Kingdom - Ksahtrap Dynasty 255 - 278 AR Drachm -
# Rudrasena II Silver 2.06g VF  BMC Delhi 581 AMF 27.1  Estimate: 25 EUR
# Starting price: 1 EUR... 26 Mar 2026 16 EUR CoinsNB - E-Auction 55,
# Lot 179 India (ancient) Western Satraps Indo-Scythian Kingdom -
# Kshaharata dynasty 119 - 124 AR Drachm - Nahapana Silver 2.06g VF  BMC
# Delhi 244 PAIC - Pieper 3351 PAIC - Pieper 3352 PAIC - Pieper 3353
# PAIC - Pieper 3354 PAIC - Pieper 3355 PAIC - Pieper 3356  Estimate: 35
# EUR  Starting price: 1 EUR... 26 Mar 2026 20 EUR Auktionshaus H. D.
# Rauch GmbH - E-Auction 48, Lot 729 BAKTRIA - Indo-Skythische Könige
# Rudrasimha III. (385-415) Drachme (2,14g) Büste mit Kappe / Berg mit
# Mond und Sternen. Fishman 38.2. Sehr leicht irisierende Tönung. ; ;
# s.sch.+  Starting price: 30 EUR... 25 Mar 2026 105 EUR Münzen Gut-Lynt
# GmbH - Auction 24, Lot 713 GRIECHISCHE MÜNZEN. Baktrien Indo-
# Skythische Könige Azes I., 57 - 35 v. Chr. Tetradrachme 57 - 35 v.
# Chr. Taxila (?). BASILEOS BASILEON MEGALOY - AZOY, Reiter mit Speer
# nach rechts. Rv. Stehende Tyche mit Palmzweig und Schale nach links,
# in den Feldern zwei Monogramme, umher Königstitulatur in Karoshti.
# Mitchiner 493, Typ 743e. 9.54 g. Sehr schön-vorzüglich / Very fine-
# Extremely fine. Feine Tönung / Light toning.  Starting price: 150
# EUR... 21 Mar 2026 190 EUR Münzen Gut-Lynt GmbH - Auction 24, Lot 714
# GRIECHISCHE MÜNZEN. Baktrien Indo-Skythische Könige Nahapana, ca. 1
# Jahrhundert n. Chr. Drachme 1. Jahrhundert n. Chr. Western Kshatrapas.
# Diademierte Büste mit Kappe nach rechts. Rv. Blitzbündel und Pfeil.
# Senior vgl. 303.1. 2.31 g. Sehr schön / Very fine. Feine Tönung /
# Light toning.  Starting price: 25 EUR... 21 Mar 2026 36 EUR Jean Elsen
# & ses Fils S.A. - Auction 164, Lot 64 lot de 10 p.: royaume de
# Nabatée, Rabel II et Shuqailat, bronze (3); royaume achéménide, sicle,
# série IIIbA; royaume élymaïde, bronze; royaume parthe, Orodes II,
# drachme; Vologases IV, drachme et dichalque; royaume sassanide,
# Khosrow II, drahm, an 8, WYHC; royaume indo-scythe, drachme. Beau Fine
# Estimate: 125 EUR... 19 Mar 2026 160 EUR Classical Numismatic Group -
# Electronic Auction 606, Lot 292 BAKTRIA, Indo-Greek Kingdom. Menander
# I Soter. Circa 155-130 BC. AR Drachm (17.5mm, 2.20 g, 12h). Diademed
# heroic bust left, seen from behind, wearing aegis and brandishing
# spear in right hand / Athena Alkedimos standing right, holding
# thunderbolt and shield; monogram to inner left. Bopearachchi 6C; SNG
# ANS; HGC 12, 187. Areas of find patina, porosity and roughness. Good
# VF.     Estimate: 100 USD... 18 Mar 2026 275 USD Classical Numismatic
# Group - Electronic Auction 606, Lot 293 BAKTRIA, Indo-Greek Kingdom.
# Menander I Soter. Circa 155-130 BC. AR Drachm (18mm, 2.29 g, 12h).
# Diademed, draped, and cuirassed bust right, wearing crested helmet
# covered with pelt of scales and adorned with head of wing / Athena
# Alkidemos advancing left; monogram to left. Bopearachchi 16E; SNG ANS
# 867; HGC 12, 193. Areas of find patina, porosity, light cleaning
# marks. Good VF.     Estimate: 100 USD... 18 Mar 2026 400 USD Classical
# Numismatic Group - Electronic Auction 606, Lot 294 BAKTRIA, Indo-Greek
# Kingdom. Zoilos III Soter. Circa 45-35 BC. AR Drachm (17.5mm, 2.34 g,
# 12h). Diademed and draped bust right / Athena Alkidemos advancing
# left; badha(?) in Kharosthi to left; to right, monogram above ji in
# Kharosthi. Bopearachchi 1M (Zoilos II); SNG ANS 1668-70 Zoilos II);
# HGC 12, 465 (Zoilos II). Iridescent toning, traces of deposits, tiny
# edge split with associated flan crack. Good VF.     Estimate: 100
# USD... 18 Mar 2026 350 USD Classical Numismatic Group - Electronic
# Auction 606, Lot 295 INDO-SKYTHIANS, Pāratarājas. Kozana. Circa AD
# 200-220. AR Drachm (15.5mm, 2.76 g, 12h). First issue with Kharosthi
# legend. Diademed bust left / Large swastika. Tandon 38; Senior 280D
# (Spajhana). Toned, areas of find patina/deposits. VF.     Estimate:
# 100 USD... 18 Mar 2026 225 USD Fritz Rudolf Künker GmbH & Co. KG -
# Auction 438, Lot 374 BABYLONIA BABYLON. AR-Tetradrachme, 322/312 v.
# Chr.; 16,95 g Baal sitzt l. mit Zepter//Löwe l. Mitchiner, Indogreek 7
# j; Nicolet-Pierre 6.   Sehr selten in dieser Erhaltung. Herrliche
# irisierende Tönung, vorzüglich  Estimate: 500 EUR... 16 Mar 2026
# 8,000 EUR Fritz Rudolf Künker GmbH & Co. KG - Auction 438, Lot 419
# BACTRIA Diodotos I., um 250 v. Chr. AV-attischer Stater mit Titel
# Antiochos II., Balkh; 8,29 g Kopf des Diodotos I. r. mit Diadem// Zeus
# steht l. und schleudert Blitz, davor N und Adler. BN Bact. -;
# Mitchiner, Indogreek 63 a; SNG ANS -, vergl. 75; Hoover 19.   R
# Prüfeinhieb auf dem Avers, vorzüglich   Exemplar der Auktion Triton
# VIII, New York 2005, Nr. 612 und der Sammlung Regierungsrat Dr. iur.
# Hans Krähenbühl, Auktion Leu Numismatik AG 8, Winterthur 2021, Nr.
# 181.   Der Prägeherr für diese ... 16 Mar 2026 4,000 EUR Fritz Rudolf
# Künker GmbH & Co. KG - Auction 438, Lot 420 BACTRIA Euthydemos I., um
# 235-200 v. Chr. AR-attische Tetradrachme, 215/210 v. Chr., Balkh;
# 16,59 g Kopf r. mit Diadem//Herakles sitzt l. mit Keule auf Felsen. BN
# Bact. 12 A; Mitchiner, Indogreek 94 a; SNG ANS 141 f; Kritt B 17;
# Hoover 43; Glenn 516 (O 147/R 360).   R Herrliche Tönung, winz.
# Stempelfehler auf dem Avers, vorzüglich   Exemplar der Sammlung Oxus,
# Auktion Roma Numismatics XXII, London 2021, Nr. 467.   Euthydemos I.
# löste die Herrschaft der Dynastie des Diodotos ab. Er konnte sich ...
# 16 Mar 2026 4,000 EUR Fritz Rudolf Künker GmbH & Co. KG - Auction 438,
# Lot 421 BACTRIA Euthydemos II., 200-190 v. Chr. AR-attische
# Tetradrachme, Balkh; 16,95 g Drapierte Büste r. mit Diadem//Herakles
# steht v. v. mit Kranz, Keule und Löwenfell. BN Bact. 1 C; Mitchiner,
# Indogreek 113 d; SNG ANS 216; Hoover 72; Glenn O 27/R 72.   R Feine
# Tönung, winz. Schrötlingsfehler auf dem Avers, vorzüglich   Exemplar
# der Sammlung Melinda, Auktion Triton XXV, New York 2022, Nr. 554.   Ex
# US-Plastikholder der NGC mit der Bewertung AU, Strike: 5/5, Surface:
# 4/5.   Ob Euthydemos II. ein So... 16 Mar 2026 1,300 EUR Fritz Rudolf
# Künker GmbH & Co. KG - Auction 438, Lot 422 BACTRIA Antimachos I.,
# 174-165 v. Chr. AR-attische Tetradrachme, Balkh; 16,78 g Drapierte
# Büste r. mit Kausia//Poseidon steht v. v. mit Dreizack und Palmzweig
# mit Taenie. BN Bact. 1 D; Mitchiner, Indogreek 124 b; SNG ANS 276;
# Hoover 106; Glenn O 33/R -.   Herrliche Tönung, winz.
# Reinigungsspuren, vorzüglich   Exemplar der Sammlung Oxus, Auktion
# Roma Numismatics XX, London 2020, Nr. 345.   Die Münzen des Antimachos
# I. unterscheiden sich durch die auffällige Kopfbedeckung des
# Herrschers deutlich... 16 Mar 2026 2,800 EUR Fritz Rudolf Künker GmbH
# & Co. KG - Auction 438, Lot 423 BACTRIA Eukratides I., 170-155 v. Chr.
# AR-attische Tetradrachme, Balkh; 16,93 g Drapierte Büste r. mit
# Diadem//Dioskuren reiten r. BN Bact. 1 D; Mitchiner, Indogreek 168 a;
# SNG ANS 432; Hoover 130.   Herrliche Tönung, prägefrisch   Exemplar
# der Sammlung Oxus, Auktion Roma Numismatics XX, London 2020, Nr. 349.
# Nachdem sich Demetrios I. Indien zugewandt hatte, gab es nördlich des
# Hindukush entweder ein Machtvakuum, oder die dortigen Griechen fühlten
# sich vernachlässigt, jedenfalls gab es 171 v... 16 Mar 2026 3,200 EUR
# Fritz Rudolf Künker GmbH & Co. KG - Auction 438, Lot 424 BACTRIA
# Eukratides I., 170-155 v. Chr. AR-attische Tetradrachme, unbestimmte
# Münzstätte (Balkh?); 16,96 g Drapierte Büste r. mit Helm//Dioskuren
# reiten r. BN Bact. 6 X; Mitchiner, Indogreek 177 e; SNG ANS 472;
# Hoover 131.  In US-Plastikholder der NGC mit der Bewertung Ch AU,
# Strike: 5/5, Surface: 4/5 (3602403-015).    Seltene Monogrammvariante.
# Sehr attraktives, gut zentriertes Exemplar, vorzüglich   Exemplar der
# Sammlung "The Everglades Collection".   Exemplar des Long Beach
# Signature Sale He... 16 Mar 2026 1,800 EUR Need access to more market
# information? Research tools for professionals Fritz Rudolf Künker GmbH
# & Co. KG - Auction 438, Lot 425 BACTRIA Eukratides I., 170-155 v. Chr.
# AR-attische Tetradrachme, unbestimmte Münzstätte (Balkh?); 16,96 g
# Drapierte Büste r. mit Helm//Dioskuren reiten r. BN Bact. 6 E;
# Mitchiner, Indogreek 177 ee; SNG ANS 465; Hoover 131.   Herrliche
# Tönung, vorzüglich   Exemplar der Auktion Lanz 86, München 1998, Nr.
# 222 und der Auktion Triton XXV, New York 2022, Nr. 560.   Ex US-
# Plastikholder der NGC mit der Bewertung Ch MS, Strike: 5/5, Surface:
# 5/5.   Nachdem sich Demetrios I. Indien zugewandt hatte, gab ... 16
# Mar 2026 1,800 EUR Fritz Rudolf Künker GmbH & Co. KG - Auction 438,
# Lot 426 BACTRIA Eukratides I., 170-155 v. Chr. AR-attische
# Tetradrachme, unbestimmte Münzstätte (Balkh?); 16,99 g Drapierte Büste
# r. mit Helm//Dioskuren reiten r. BN Bact. 6 E; Mitchiner, Indogreek
# 177 ee; SNG ANS 465; Hoover 131.  In US-Plastikholder der NGC mit der
# Bewertung Ch AU, Strike: 5/5, Surface: 5/5 (4934010-002).    Herrliche
# Tönung, vorzüglich   Exemplar der Sammlung "The Everglades
# Collection".  Dieses Los unterliegt der Regelbesteuerung. / This lot
# cannot be sold under the margin scheme.... 16 Mar 2026 1,400 EUR Fritz
# Rudolf Künker GmbH & Co. KG - Auction 438, Lot 427 BACTRIA Eukratides
# I., 170-155 v. Chr. AR-attische Tetradrachme, unbestimmte Münzstätte
# (Balkh?); 16,99 g Drapierte Büste r. mit Helm//Dioskuren reiten r. BN
# Bact. 6 E; Mitchiner, Indogreek 177 ee; SNG ANS 465; Hoover 131.
# Feine Tönung, vorzüglich   Exemplar der Sammlung "The Everglades
# Collection".   Nachdem sich Demetrios I. Indien zugewandt hatte, gab
# es nördlich des Hindukush entweder ein Machtvakuum, oder die dortigen
# Griechen fühlten sich vernachlässigt, jedenfalls gab es 171 v. Chr.
# e... 16 Mar 2026 1,000 EUR Fritz Rudolf Künker GmbH & Co. KG - Auction
# 438, Lot 428 INDIA Menander, 155-130 v. Chr. AR-indische Drachme,
# unbestimmte Münzstätte; 2,54 g Büste l. mit Pantherfell und Speer vom
# Rücken gesehen//Athena Alkidemos geht r. mit Aegis und Blitz. BN Bact.
# 6 C; Mitchiner, Indogreek 221 d; SNG ANS 716; Hoover 187.   Feine
# Tönung, vorzüglich   Exemplar der Auktion Triton XXV, New York 2022,
# Nr. 6267 (dort im US-Plastikholder der NGC mit der Bewertung Ch AU ★,
# Strike: 5/5, Surface: 5/5).   Menander war der bedeutendste der
# griechischen Herrscher in Indien. Z... 16 Mar 2026 500 EUR Fritz
# Rudolf Künker GmbH & Co. KG - Auction 438, Lot 429 INDIA Menander,
# 155-130 v. Chr. AR-indische Drachme, unbestimmte Münzstätte; 2,47 g
# Drapierte Büste r. mit Helm//Athena Alkidemos l. mit Schild und Blitz.
# BN Bact. 16 E; Mitchiner, Indogreek 218 b; SNG ANS 868; Hoover 193.
# Feine Tönung, winz. Stempelfehler auf dem Avers, vorzüglich   Exemplar
# der Sammlung K. G. (erworben in den 1960er Jahren bis 2003), Auktion
# Giessener Münzhandlung 284, München 2022, Nr. 450.  Estimate: 75
# EUR... 16 Mar 2026 160 EUR Fritz Rudolf Künker GmbH & Co. KG - Auction
# 438, Lot 430 INDIA Zoilos, 130-120 v. Chr. AR-indische Drachme,
# unbestimmte Münzstätte; 2,43 g Drapierte Büste r. mit Diadem//Herakles
# steht v. v. mit Kranz, Keule und Löwenfell. BN Bact. 3 B; Mitchiner,
# Indogreek 256 b; SNG ANS 968 ff; Hoover 218.   RR Feine Tönung, gutes
# vorzüglich   Exemplar der Auktion Sternberg XXVII, Zürich 1994, Nr.
# 38; der Auktion Tkalec, Zürich 29. Februar 2000, Nr. 206; der Sammlung
# Pierre Strauss und der Auktion NAC 132, Zürich 2022, Nr. 387.
# Estimate: 500 EUR... 16 Mar 2026 2,200 EUR Fritz Rudolf Künker GmbH &
# Co. KG - Auction 438, Lot 431 INDIA Antialkidas, 115-100 v. Chr. AR-
# indische Drachme, Panjhir; 2,47 g Drapierte Büste r. mit Kausia//Zeus
# Nikephoros sitzt l., davor Elefantenprotome l. BN Bact. 13 A;
# Mitchiner, Indogreek 277 a; SNG ANS 1085 ff; Hoover 259.   Herrliche
# Patina, sehr schön-vorzüglich   Exemplar der Auktion Triton XXV, New
# York 2022, Nr. 5188.  Estimate: 100 EUR... 16 Mar 2026 340 EUR Fritz
# Rudolf Künker GmbH & Co. KG - Auction 438, Lot 432 INDIA Amyntas,
# 95-90 v. Chr. AR-Drachme, unbestimmte Münzstätte; 2,53 g Büste l. mit
# Aegis, Diadem und Speer//Zeus Nikephoros sitzt l. BN Bact. 9 B;
# Mitchiner, Indogreek 392 a; SNG ANS 1248; Hoover 425.   Sehr selten,
# besonders in dieser Erhaltung. Leichte Auflagen, fast Stempelglanz
# Exemplar der Sammlung Rubellite, Auktion Roma Numismatics XXIII,
# London 2022, Nr. 466.  Estimate: 750 EUR... 16 Mar 2026 1,900 EUR
# Fritz Rudolf Künker GmbH & Co. KG - Auction 438, Lot 433 INDIA
# Hermaios, 90-70 v. Chr. AR-indische Tetradrachme, unbestimmte
# Münzstätte; 9,28 g Drapierte Büste r. mit Diadem//Zeus thront halbl.
# mit Zepter. BN Bact. 2 G; Mitchiner, Indogreek 414 l; Senior, Hermaios
# H3bT; Hoover 290.   Feine Tönung, vorzüglich   Exemplar der Sammlung
# K. G. (von diesem erworben vor 2004), Auktion Giessener Münzhandlung
# 284, München 2022, Nr. 459.   Hermaios war der letzte griechische
# König in Paropanisadae, bevor die Skythen das Land eroberten. Die
# Ikonografie der grea... 16 Mar 2026 1,050 EUR Leu Numismatik AG - Web
# Auction 40, Lot 982 BAKTRIA, Greco-Baktrian Kingdom. Eukratides I,
# circa 170-145 BC. Tetradrachm (Silver, 33 mm, 15.88 g, 12 h), dynastic
# pedigree issue. Baktra, circa 162-145. BAΣIΛEYΣ MEΓAΣ / EΥKΡATIΔHΣ
# Diademed and draped bust of Eukratides to right, wearing Macedonian
# helmet adorned with bull's horn and ear. Rev. HΛIOΚΛHOYΣ / KAI
# ΛAOΔIKHΣ Jugate busts of Heliokles, bare-headed and draped, and
# Laodike, diademed and draped, to right; behind, monogram. Bopearachchi
# Série 13. HGC 12, 133. Somewhat rough, otherwis... 14 Mar 2026
# 2,400 CHF Leu Numismatik AG - Web Auction 40, Lot 984 BAKTRIA, Indo-
# Greek Kingdom. Antialkidas, circa 130-120 BC. Drachm (Silver, 16 mm,
# 2.41 g, 12 h), Indian standard, uncertain mint in Paropamisadai or
# Gandhara. ΒΑΣΙΛΕΩΣ ΝΙΚΗΦΟΡΟΥ / ΑΝΤΙΑΛΚΙΔΟΥ Diademed, draped, and
# cuirassed bust of Antialkidas to right, wearing kausia. Rev.
# 'Maharajasa jayadharasa Amtialkidasa' (in Kharoshti) Zeus seated
# facing slightly to left, holding Nike in his right hand and scepter in
# his left; to left, forepart of elephant left; below throne, monogram.
# Bopearachchi 13C... 14 Mar 2026 120 CHF Leu Numismatik AG - Web
# Auction 40, Lot 985 BAKTRIA, Indo-Greek Kingdom. Hermaios, circa
# 105-90 BC. Drachm (Silver, 16 mm, 2.41 g, 12 h), uncertain mint in the
# Paropamisadai. BAΣIΛEΩΣ ΣΩTHPOΣ - EPMAIOY Diademed and draped bust of
# Hermaios to right. Rev. 'Maharajasa tratarasa Heramayasa' ('of the
# Great King Hermaios the Savior' in Karoshti) Zeus seated slightly to
# left, raising his right hand and holding scepter in his left; to
# right, monogram. Bopearachchi 3E. HGC 12, 293. MIG 415i. SNG ANS
# 1338-40. Nicely toned. Very fine.   From the c... 14 Mar 2026 160 CHF
# Leu Numismatik AG - Web Auction 40, Lot 986 BAKTRIA, Indo-Greek
# Kingdom. Apollodotos II, circa 85-65 BC. Drachm (Silver, 17 mm, 2.40
# g, 12 h), uncertain mint in the eastern Punjab. BAΣIΛEΩΣ ΣΩTHPOΣ ΚΑΙ
# ΦΙΛΟΠΑΤΟΡΟΣ / AΠOΛΛOΔOTOY Diademed and draped bust of Apollodotos II
# to right. Rev. 'Maharajasa tratarasa Apaladatasa' ('of Great King
# Apollodotos the Savior' in Kharoshti) Athena Promachos advancing left,
# holding shield on left arm and brandishing thunderbolt with her right;
# in field to right, monogram. Bopearachchi 2D. HGC 12, 392. SNG ... 14
# Mar 2026 60 CHF Leu Numismatik AG - Web Auction 40, Lot 987 BAKTRIA,
# Indo-Greek Kingdom. Zoilos III, circa 45-35 BC. Drachm (Silver, 17 mm,
# 2.36 g, 11 h), uncertain mint in the eastern Punjab. BAΣIΛEΩΣ ΣΟΤΗΡΟC
# / ZΩIΛOΥ Diademed and draped bust of Zoilos II to right. Rev.
# 'Maharajasa tratarasa Jhoilasa' ('of the Great King Zoilos the Savior'
# in Karoshti) Athena Promachos advancing left, holding shield on her
# left arm and brandishing thunderbolt with her right; to left, Karoshti
# letter; to right, monogram above Karoshti letter. Bopearachchi 1N
# (Zoilos II... 14 Mar 2026 130 CHF Leu Numismatik AG - Web Auction 40,
# Lot 988 INDO-SKYTHIANS. Maues, circa 125-85 BC. AE (Bronze, 22x20 mm,
# 9.49 g, 12 h), Taxila. [B]AΣIΛEΩΣ BAΣIΛEΩN MEΓAΛOY MAY[OY] Elephant
# standing right, right foreleg raised. Rev. 'Rajadirajasa mahatasa
# Moasa' ('of Great King of Kings Maues' in Karoshti) Maues seated
# cross-legged on couch with sword on lap; to right, monogram. HGC 12,
# 543. Senior 15.1. Some deposits and light scratches and with minor
# traces of cleaning, otherwise,  nearly very fine. This lot cannot be
# shipped to a US address.  When d... 14 Mar 2026 90 CHF Leu Numismatik
# AG - Web Auction 40, Lot 989 INDO-SKYTHIANS. Azes, circa 58-12 BC.
# Tetradrachm (Silver, 27 mm, 9.35 g, 12 h), Indian standard, uncertain
# mint in western Gandhara. BACIΛEΩC BACIΛEΩN MEΓAΛ[OY] / [AZOY] King on
# horseback to right, holding spear in his right hand. Rev. 'Maharajasa
# rajarajasa mahatasa Ayasa' ('of Great King, King of Kings Azes the
# Great' in Karoshti) Zeus standing facing, holding thunderbolt in his
# right hand and long scepter in his left; to left and right, monogram.
# HGC 12, 626 var. (monogram and letter on re... 14 Mar 2026 160 CHF Leu
# Numismatik AG - Web Auction 40, Lot 990 INDO-SKYTHIANS, Paratarajas.
# Koziya, circa 235-255. Drachm (Bronze, 14 mm, 1.38 g), late-reign
# issue. Draped bust of Koziya to right, wearing an Indian turban. Rev.
# 'Koziyasa Kozanaputrasa Pāratarājasa' ('of Koziya, son of Kozana, king
# of the Paratas' in kharoṣṭhī) around swastika. Tandon 55. Light
# scratches, otherwise,  very fine.   Ex Leu Web Auction 38, 13-14
# December 2025, 1063 and previously from a Canadian collection, formed
# before 2005. This lot cannot be shipped to a US address.    Sta... 14
# Mar 2026 85 CHF Leu Numismatik AG - Web Auction 40, Lot 991 INDO-
# SKYTHIANS, Western Satraps. Nahapana, circa 53-99. Drachm (Silver, 18
# mm, 2.33 g, 6 h). PANNIⲰ ΣΑHAPATAC NAHAPANAC Head of Nahapana to
# right. Rev. RaJno KsaHaRaTaSa NaPaNaSa (in Brahmi on the left) and
# RaNo KsaHaRaTaSa NaHaPaNaSa (in Kharoshthi on the right) Stylized
# thunderbolt and arrow. Fishman Type 3.1. A fresh and attractive piece
# with a beautiful portrait. Minor areas of weakness and the reverse
# struck slightly off center, otherwise,  nearly extremely fine.   From
# the Murli Narayan ... 14 Mar 2026 50 CHF Leu Numismatik AG - Web
# Auction 40, Lot 992 INDO-SKYTHIANS, Western Satraps. Nahapana, circa
# 53-99. Drachm (Silver, 17 mm, 2.18 g, 4 h). PANNIⲰ ΣΑHAPATAC NAHAPANAC
# Head of Nahapana to right. Rev. RaJno KsaHaRaTaSa NaPaNaSa (in Brahmi
# on the left) and RaNo KsaHaRaTaSa NaHaPaNaSa (in Kharoshthi on the
# right) Stylized thunderbolt and arrow. Fishman Type 3.1. Struck from
# somewhat worn dies, otherwise,  good very fine.   From the Murli
# Narayan Collection (with collector's ticket).  Nahapana, son of
# Bhumaka, was arguably the greatest ruler of... 14 Mar 2026 95 CHF
# Timeline Auctions - Auction 170, Lot 2740 Indo-Scythians, Azes AR
# Drachm. Circa 58-12 BC. Azes on horseback to right, holding whip;
# Kharosthi letter before / Zeus standing to left, holding Nike and
# sceptre; monogram to left; Kharosthi letter(?) to right. HGC 12, 655.
# 1.88gr, 14mm, 7h.  Good Fine.  From the private collection of John
# Meredith, acquired since the 1990s; thence by descent.    TimeLine
# Auctions follows a rigorous vetting process to ensure the authenticity
# and legality of all items, reinforcing our commitment to integrity...
# 10 Mar 2026 15 GBP Need access to more market information? Research
# tools for professionals Timeline Auctions - Auction 170, Lot 2741
# Indo-Scythians, Azes AR Drachm. Circa 58-12 BC. Azes on horseback to
# right, wearing cataphractus and holding whip aloft; Karosthi letter
# before horse / Zeus Nikephoros standing to left, holding transverse
# sceptre; monogram to left, Karoshthi letter to right. Cf. Senior
# 105.500D; HGC 12, 655.  2.00gr, 15mm, 7h.  Good Very Fine.  Ex
# Lockdales. From the private collection of John Meredith, acquired
# since the 1990s; thence by descent.    TimeLine Auctions follows a
# rigorous vetting process to ensu... 10 Mar 2026 110 GBP Timeline
# Auctions - Auction 170, Lot 2742 Indo-Greek Kingdom, Philoxenos
# Aniketos AE Double Unit(?). Circa 125-110 BC. Square module. ΒΑΣΙΛΕΩΣ
# ΑΝΙΚΗΤΟΥ ΦΙΛΟΞΕΝΟΥ, Tyche standing to left, raising hand and holding
# cornucopia; monogram to lower left / Zebu standing to right; Σ below.
# Bopearachchi 10H; SNG ANS 1209-14; HGC 12, 274.  8.56gr, 20mm, 12h.
# Very Fine.  Acquired from CGB. From the Nick Collins collection. Ex
# Roma Numismatics Ltd, E-Sale 78, 17 December 2020, lot 700. Property
# of a London antiquarian.    TimeLine Auctions follow... 10 Mar 2026
# 140 GBP Rio de la Plata - Online Auction 25, Lot 474 Indo-Scythian
# Kingdom. Azes II (c.35-12BC) Tetradrachm. Silver; 26.5mm; 7.56g. A:
# BAΣIΛEΩΣ BAΣIΛEΩN MEΓAΛOY - AZOY, Azes on horseback right, holding
# whip and spear; Kharosthi letter before. R: «Maharaja rajadirajasa
# mahatasa Ayasa» (in Karoshti), Zeus Nikephoros standing left with
# sceptre; monogram to left, karoshthi letters to right. Mitchiner 2397.
# (VF)  Estimate: 100 - 150 USD... 10 Mar 2026 50 USD Jesus Vico S.A. -
# Auction 178, Lot 1093 GRECIA ANTIGUA. IMPERIO INDO-ESCITA. Apolodoto
# I. Hemióbolo (170-164 a.C.). A/ Apolo a izq., delante monograma. R/
# Trípode dentro de gráfila de puntos cuadrada. AR 9,82 g. 22,6 mm.
# COP-338 ss. var. monograma. MBC.     Starting price: 40 EUR... 5 Mar
# 2026 135 EUR Jesus Vico S.A. - Auction 178, Lot 1094 GRECIA ANTIGUA.
# IMPERIO INDO-ESCITA. Hermeo. Dracma (90-70 a.C.). A/ Cabeza diademada
# y drapeada a der. R/ Zeus entronizado a izq., delante monograma poco
# visible. AR 2,06 g. 15,9 mm. COP-360 var. monograma. MBC+/MBC-.
# Starting price: 35 EUR... 5 Mar 2026 75 EUR Jesus Vico S.A. - Auction
# 178, Lot 1095 GRECIA ANTIGUA. IMPERIO INDO-ESCITA. Azes I. Taxila.
# Dracma (57-35 a.C.). A/ Jinete a der., delante monograma. R/ Atenea a
# der., en campo monogramas. AR 2,52 g. 16,6 mm. MBC+.     Starting
# price: 40 EUR... 5 Mar 2026 55 EUR Jesus Vico S.A. - Auction 178, Lot
# 1096 GRECIA ANTIGUA. IMPERIO INDO-ESCITA. Azes II. Tetradracma (20-21
# d.C.). A/ Jinete a der. R/ Figura estante. AR 9,46 g. 24,4 mm.
# Mit.-2668. EBC-/MBC+.     Starting price: 40 EUR... 5 Mar 2026 140 EUR
# Jesus Vico S.A. - Auction 178, Lot 1097 GRECIA ANTIGUA. IMPERIO INDO-
# ESCITA. Azes II. Pentacalco (35-5 a.C.). A/ Jinete a der. R/ Cebú a
# der. AE 9,39 g. 22,4 x 21,7 mm. Mit.-2327. MBC-/MBC.     Starting
# price: 35 EUR... 5 Mar 2026 85 EUR Jesus Vico S.A. - Auction 178, Lot
# 1098 GRECIA ANTIGUA. IMPERIO INDO-ESCITA. Antialcidas. Dracma (130-95
# a.C.). A/ Busto diademado a der. R/ Zeus sentado a izq. con victoria,
# debajo del trono monograma y delante elefante. AR 2,33 g. 17,4 mm.
# COP-316 var. monogr. Finas rayas. MBC/MBC+.     Starting price: 60
# EUR... 5 Mar 2026 110 EUR Classical Numismatic Group - Electronic
# Auction 605, Lot 412 BAKTRIA, Indo-Greek Kingdom. Menander I Soter.
# Circa 155-130 BC. AR Drachm (18.5mm, 2.31 g, 12h). Diademed heroic
# bust left, seen from behind, wearing aegis and brandishing spear in
# right hand / Athena Alkedimos standing right, holding thunderbolt and
# shield; monogram to inner left. Bopearachchi 6C; SNG ANS 715-21; HGC
# 12, 187. Areas of find patina, slight roughness. Good VF.
# Estimate: 100 USD... 4 Mar 2026 190 USD Classical Numismatic Group -
# Electronic Auction 605, Lot 413 BAKTRIA, Indo-Greek Kingdom. Menander
# I Soter. Circa 155-130 BC. AR Drachm (18mm, 2.29 g, 12h). Diademed,
# draped, and cuirassed bust right, wearing crested helmet covered with
# pelt of scales and adorned with wing / Athena Alkidemos advancing
# left; monogram to right. Bopearachchi 16E; SNG ANS 868; HGC 12, 193.
# Areas of find patina, porosity, worn reverse die. Good VF.
# Estimate: 100 USD... 4 Mar 2026 180 USD Classical Numismatic Group -
# Electronic Auction 605, Lot 414 BAKTRIA, Indo-Greek Kingdom.
# Agathokleia & Strato I Soter. Circa 105-85/0 BC. Æ (24x20mm, 8.63 g,
# 12h). Square module. Helmeted and draped bust of Athena right /
# Herakles seated facing slightly left, leaning on rock outcropping,
# holding club set on knee; monogram to left. Bopearachchi 3A; SNG ANS
# 983-5; HGC 12, 317. Earthen dark brown patina, slight porosity,
# cleaning marks. VF.     Estimate: 100 USD... 4 Mar 2026 375 USD
# Classical Numismatic Group - Electronic Auction 605, Lot 415 BAKTRIA,
# Indo-Greek Kingdom. Heliokles II Dikaios. Circa 90-75 BC. Æ (23x20mm,
# 8.27 g, 12h). Square module. Diademed and draped bust right / Elephant
# standing left; monogram to below. Bopearachchi 7B; SNG ANS 1152; HGC
# 12, 384. Earthen black-green patina, cleaning marks. VF.     Estimate:
# 100 USD... 4 Mar 2026 325 USD Classical Numismatic Group - Electronic
# Auction 605, Lot 416 BAKTRIA, Indo-Greek Kingdom. Zoilos II Soter.
# Circa 65-55 BC. AR Drachm (17mm, 2.30 g, 12h). Diademed and draped
# bust right / Athena Alkidemos advancing left; to left, B/I; monogram
# to right. Bopearachchi 1J; SNG ANS –; HGC 12, 465. Areas of find
# patina. VF.     Estimate: 100 USD... 4 Mar 2026 275 USD Classical
# Numismatic Group - Electronic Auction 605, Lot 417 BAKTRIA, Indo-Greek
# Kingdom. Zoilos III Soter. Circa 45-35 BC. AR Drachm (17mm, 2.35 g,
# 12h). Diademed and draped bust right / Athena Alkidemos advancing
# left; badha(?) in Kharosthi to left; to right, monogram above ji in
# Kharosthi. Bopearachchi 1M (Zoilos II); SNG ANS 1668-70 Zoilos II);
# HGC 12, 465 (Zoilos II). Iridescent toning, traces of deposits, double
# strike and flan flaws on reverse. Good VF.     Estimate: 100 USD... 4
# Mar 2026 650 USD Classical Numismatic Group - Electronic Auction 605,
# Lot 420 INDO-SKYTHIANS. Azes. Circa 58-12 BC. AR Drachm (18mm, 2.23 g,
# 12h). Zeus standing left, holding torque and scepter / Nike standing
# right, holding wreath with angled fillets and palm frond with long
# flowing fillets; monogram to inner right. Senior 76.3D; HGC 12, 640.
# Iridescent toning, porosity, tiny edge flaw. Good VF.     Estimate:
# 100 USD... 4 Mar 2026 225 USD Classical Numismatic Group - Electronic
# Auction 605, Lot 421 INDO-SKYTHIANS, Pāratarājas. Hvaramira. Circa AD
# 165-175. AR Drachm (17mm, 3.69 g, 6h). Early issue. Diademed and
# draped bust right / Retrograde swastika. Tandon 17-18 var. (swastika
# not retrograde); cf. Senior S58.1D. Thick deposits on reverse. Good
# VF.     Estimate: 100 USD... 4 Mar 2026 200 USD Classical Numismatic
# Group - Electronic Auction 605, Lot 422 INDO-SKYTHIANS, Pāratarājas.
# Kozana. Circa AD 200-220. AR Hemirachm (11.5mm, 1.47 g, 12h). First
# issue with Kharosthi legend. Crowned and draped bust left / Large
# swastika. Tandon 39; Senior Senior 280.1H and S44.2H (Spajhana). Areas
# of find patina and peripheral weakness. Good VF.     Estimate: 100
# USD... 4 Mar 2026 300 USD Classical Numismatic Group - Electronic
# Auction 605, Lot 450 INDO-SASANIAN, Sind. Ranaditya Satya. Circa AD
# 480. Pale AV Dinar (18mm, 6.85 g, 9h). Crowned Peroz-style bust right;
# sun symbol to right / Fire altar; ranaditya in Brahmi down right,
# satya in Brahmi up left. F&T pp. 62-3 and fig. 4.10; cf. Senior, "Some
# new coins from Sind," ONS Newsletter 149 (Summer 1996), p. 6, 3.
# Toned, granular surfaces. Near VF.   From the James A. Lock
# Collection. Ex Classical Numismatic Group Electronic Auction 59 (27
# February 2003), lot 95.    Estimate: 100 USD... 4 Mar 2026 400 USD Ira
# & Larry Goldberg Coins & Collectibles - Auction 150, Lot 445 Trio of
# Ancient Greek Silver Coins all NGC Graded. Consists of: 1. Cyprus,
# Citium. Baalmelek II c. 425-400 BC 1/6th stater. Choice Fine. 2.
# Cyprus, Salamis, Evagoras I, c. 411-374 BC. 1/24th stater. Choice Very
# Fine. 3. Indo-Scythians, Azes I/II after c. 58 BC. Drachm. Extremely
# Fine . Lot of 3 coins. Ex The Peter Preovolos Collection.... 23 Feb
# 2026 160 USD Need access to more market information? Research tools
# for professionals Ira & Larry Goldberg Coins & Collectibles - Auction
# 150, Lot 557 Bactria. Indo-Scythians. Azes I, after c. 58 BC. Silver
# Tetradrachm (9.23g). King Azes crowning prancing horse to r. Reverse:
# Pallas standing r. holding shield and spear. Mitchner Vol. 6, 84-6.
# Lightly toned. NGC graded VF, Strike: 4/5, Surface: 3/5.  Estimated
# Value $200 - UP... 23 Feb 2026 Unsold Tauler & Fau - Auction 167, Lot
# 151 Indo-Greek Kingdom. Menander I Soter. Drachm. 165/155-130 BC.
# (Bopearachchi-13Q). (Sng Ans-822/41). (Hgc-12,191). Anv.: BAΣIΛEΩΣ
# ΣΩTHPOΣ MENANΔPOY, diademed and draped bust right. Rev.: Athena
# Alkidemos advancing left, shield decorated with aegis over arm,
# hurling thunderbolt; monogram to left; Karosthi inscription around.
# Ag. 2,37 g. Old cabinet tone. Choice VF. Est...90,00.   Spanish
# description: Reino de Indogrecia. Menander I Soter. Dracma.
# 165/155-130 a.C. (Bopearachchi-13Q). (Sng Ans-822... 23 Feb 2026
# 65 EUR Tauler & Fau - Auction 167, Lot 152 Indo-Greek Kingdom.
# Menander I Soter. Dichalkon. 165/55-130 BC. (Bopearachchi-24A).
# (Hgc-12, 199). Anv.: ΒΑΣΙΛΕΩΣ-ΣΩΤΗΡΟΣ-ΜΕΝΑΝΔΡΟΥ, helmeted head of
# Athena right. Rev.: Maharajasa tratarasa Mendrasa (Kharosthi), free
# horse prancing right; HΔTM monogram below. Ae. 36,08 g. Tooled and
# smoothed. Rare. XF/Choice VF. Est...500,00.   Spanish description:
# Reino de Indogrecia. Menander I Soter. Dichalkon. 165/55-130 a.C.
# (Bopearachchi-24A). (Hgc-12, 199). Anv.: ΒΑΣΙΛΕΩΣ-ΣΩΤΗΡΟΣ-ΜΕΝΑΝΔΡΟΥ.
# Cabeza con ... 23 Feb 2026 400 EUR Tauler & Fau - Auction 167, Lot 183
# Indo-Skythians. Maues. Tetradrachm. 95-57 BC. Taxila. (Senior-1.1T).
# (Hgc-12, 524). Anv.: BAΣIΛEΩΣ BAΣIΛEΩN MEΓΛΛOY MAYOY, Zeus standing to
# left, extending right hand and holding long sceptre. Rev.:
# 'Rajadirajasa mahatasa Moasa' in Kharosthi, Nike standing to right,
# holding wreath and palm over shoulder; monogram to right. Ag. 9,32 g.
# Delicate patina. Choice VF. Est...400,00.   Spanish description:
# Indoescitas. Maues. Tetradracma. 95-57 a.C. Taxila. (Senior-1.1T).
# (Mitchiner-729a). (Hgc-12, 52... 23 Feb 2026 210 EUR Tauler & Fau -
# Auction 167, Lot 184 Indo-Skythians. Azes I. Tetradrachm. 58-12 BC.
# Uncertain mint in western Gandhara. (Hgc-12, 637). (Senior-98.354T).
# Anv.: BAΣIΛEΩΣ BAΣIΛEΩN MEΓAΛOY / AZOY King on horseback to right,
# raising his right hand and holding whip in his left; to right,
# Karoshti 'i'. Rev.: 'Maharajasa rajarajasa mahatasa Ayasa' ('of Great
# King, King of Kings Azes the Great' in Karoshti) Athena standing
# facing, raising her right hand in blessing and holding shield in her
# left; behind her back, spear; to left and right,... 23 Feb 2026
# 110 EUR Tauler & Fau - Auction 167, Lot 185 Indo-Skythians. Azes I.
# Drachm. 58-12 BC. (Senior-105.375D). (Hgc-12, 655). Anv.: Azes on
# horseback to right, wearing cataphractus and holding whip aloft;
# Karosthi letter before horse. Rev.: Zeus Nikephoros standing to left,
# holding transverse sceptre; monogram to left, Karoshthi letter to
# right. Ag. 2,40 g. A good sample for this type. Slight patina. Choice
# VF. Est...120,00.   Spanish description: Indoescitas. Azes I. Dracma.
# 58-12 a.C. (Senior-105.375D). (Hgc-12, 655). Anv.: Azes a caballo a...
# 23 Feb 2026 75 EUR Naville Numismatics Ltd. - Auction 100, Lot 80
# Kings of the Scythians, Maues, circa 125-85 Indo-Scythians Bronze
# circa 125-85, Æ 25.00 mm., 9.76 g. Artemis, radiate, standing r. Rev.
# Zebu standing l.; monogram to l.. Senior 13.2; HGC 12, 532.  Rare.
# Earthen brown patina, coppery highlights, a few light marks, hint of
# smoothing. Very fine  Ex CNG e-sale 557, 192.  Starting price: 25
# GBP... 22 Feb 2026 95 GBP Naville Numismatics Ltd. - Auction 100, Lot
# 270 Parthia, Indo-Parthia Balkh issue. Drachm , AR 17.00 mm., 4.26 g.
# Helmeted bust r.. Rev. Helmetd bust r.  Countermark on obverse. Dar
# tone and Good Fine  Starting price: 20 GBP... 22 Feb 2026 280 GBP
# Naville Numismatics Ltd. - Auction 100, Lot 293 Bactria, Indo-Greek
# Kingdom, Menander I Soter 155-130 Drachm circa 155-130, AR 16.00 mm.,
# 2.33 g. Diademed and draped bust right. Rev. Athena Alkidemos
# advancing left; holding shield decorated with aegis and hurling
# thunderbolt; in right field, monogram. Bopearachchi 13O. SNG ANS 808.
# Very fine  Starting price: 25 GBP... 22 Feb 2026 60 GBP Naville
# Numismatics Ltd. - Auction 100, Lot 294 Bactria, Indo-Greek Kingdom.
# Zoilos I Dikaios, circa 150-130 Drachm circa 150-130, AR 15.00 mm.,
# 1.16 g. Diademed and draped bust r. Rev. Heracles standing facing,
# holding wreath and club; monogram to inner l. Bopearachchi 3F var.
# Old cabinet tone and Good Very fine  Starting price: 80 GBP... 22 Feb
# 2026 90 GBP Wojcicki Polish Auction House - Premium Auction 17, Lot
# 11006 Greece, Indo-Scythians, Azes I, Tetradrachm  Greece  Indo-
# Scythians, Azes I (58-12 BC), Tetradrachm, Taxila mint   Obverse: Azes
# on horseback right, holding whip and spear  Reverse: Athena standing
# right, holding Nike in right hand, raising hand and holding spear and
# shield, monograms to left and right  Diameter 25 mm, weight 9.54 g
# Grecja  Indo-Scytowie, Król Azes I (58-12 pne), Tetradrachma, mennica
# Taxila   Awers: król siedzący na koniu w prawo, trzymający bicz i
# włócznię   BAΣIΛEΩΣ BAΣ... 21 Feb 2026 82 EUR Wojcicki Polish Auction
# House - Premium Auction 17, Lot 11007 Greece, Indo-Scythians, Azes II,
# Tetradrachm  Greece  Indo-Scythians, Azes II (58-12 BC), Tetradrachm
# 35-12, Taxila mint   Obverse: Azes on horseback right, holding whip
# and spear  Reverse: Pallas, standing right  Diameter 25 mm, weight
# 9.59 g   Grecja  Indo-Scytowie, Król Azes II (58-12 pne), Tetradrachma
# 35-12, mennica Taxila   Awers: król siedzący na koniu w prawo,
# trzymający bicz i włócznię   BAΣIΛEΩΣ BAΣIΛEΩN MEΓAΛOY AZOY   Rewers:
# Pallas, stojąca w prawo   Średnica 25 mm, waga 9.59 g R... 21 Feb 2026
# 82 EUR Classical Numismatic Group - Electronic Auction 604, Lot 376
# BAKTRIA, Indo-Greek Kingdom. Archebios Dikaios Nikephoros. Circa 75-65
# BC. Æ (25x25mm, 11.30 g, 12h). Square module. Elephant standing right
# / Owl standing right, head facing; monogram below. Bopearachchi 12B;
# SNG ANS 1307-13; HGC 12, 443. Earthen dark green patina, some stable
# green deposits. Good VF.   Ex Classical Numismatic Group Electronic
# Auction 557 (6 March 2024), lot 185.    Estimate: 200 USD... 18 Feb
# 2026 325 USD Classical Numismatic Group - Electronic Auction 604, Lot
# 378 INDO-SKYTHIANS. Azes. Circa 58-12 BC. AR Tetradrachm (25mm, 9.61
# g, 12h). King on horseback right, holding whip; gam? in Kharosthi to
# right / Athena standing right, holding spear and shield and raising
# right hand in benediction; monogram to left;  so in Kharosthi to
# right. Senior 98.303T; HGC 12, 637; Dow, ACTTB, p. 115 (this coin).
# Light iridescence, areas of weak strike. EF.   From the Joseph A. Dow
# Collection. Ex Classical Numismatic Group Electronic Auction 186 (16
# April 2008), lot 57.  Th... 18 Feb 2026 190 USD Numimarket.pl -
# E-Auction 10, Lot 55 Greece, Bactria, Indo-Greek Kingdom, Hermaios
# 105-90 BC, Drachma  Weight 1,76 g, diameter 17 mm. A bilingual coin
# with legends in Greek and Kharoshthi.  Waga 1,76 g, średnica 17 mm.
# Rzadsza, późna drachma dwujęzyczna. Ciemna, oryginalna patyna. Awers:
# popiersie Hermaiosa skierowane w prawo, wokół legenda w języku greckim
# BAΣIΛEΩΣ ΣΩTHPOΣ EPMAIOY. Rewers: Zeus siedzący na tronie, unoszący
# rękę i trzymający berło, wokół legenda w języku kharoshthi.Reference:
# SNG ANS 1407 Grade: VF+  Starting p... 8 Feb 2026 29 EUR Numimarket.pl
# - E-Auction 10, Lot 58 Indo-Scythian Kingdom, Azes 58-12 BCE, Drachma
# Weight 2,31 g, diameter 15 mm. A well-preserved coin for this type,
# with its original patina highlighting the details of the relief. A
# bilingual coin with legends in Greek and Kharoshthi.  Waga 2,31 g,
# średnica 15 mm. Ładnie zachowana jak na ten typ moneta w oryginalnej
# patynie podkreślającej detale reliefu. Awers: Azes jadący na koniu w
# prawo, wokół legenda w języku greckim BAΣIΛEΩΣ BAΣIΛEΩN MEΓAΛOY AZOY.
# Rewers: Atena w hełmie, z włócznią i t... 8 Feb 2026 39 EUR
# Numimarket.pl - E-Auction 10, Lot 59 Indo-Scythian Kingdom, Azes 58-12
# BCE, Drachma  Weight 2,30 g, diameter 16 mm. A bilingual coin with
# legends in Greek and Kharoshthi.  Waga 2,30 g, średnica 16 mm. Awers:
# Azes jadący na koniu w prawo, wokół legenda w języku greckim BAΣIΛEΩΣ
# BAΣIΛEΩN MEΓAΛOY AZOY. Rewers: Atena w hełmie, z włócznią i tarczą
# stojąca w prawo, po jej obu stronach monogramy, wokół legenda w języku
# kharoshthi.Reference: HGC 12, 653 Grade: VF+  Starting price: 13
# EUR... 8 Feb 2026 34 EUR Numimarket.pl - E-Auction 10, Lot 60 Indo-
# Scythian Kingdom, Azes 58-12 BCE, Drachma  Weight 2,31 g, diameter 15
# mm. A bilingual coin with legends in Greek and Kharoshthi.  Waga 2,31
# g, średnica 15 mm. Awers: Azes jadący na koniu w prawo, wokół legenda
# w języku greckim BAΣIΛEΩΣ BAΣIΛEΩN MEΓAΛOY AZOY. Rewers: Zeus stojący
# w lewo, trzymający małą Nike na wyciągniętej dłoni i długie berło, w
# polu monogramy, wokół legenda w języku kharoshthi.Reference: Senior
# 105.160 Grade: XF-/VF+  Starting price: 25 EUR... 8 Feb 2026 34 EUR
# Numimarket.pl - E-Auction 10, Lot 61 Indo-Scythian Kingdom, Azes 58-12
# BCE, Drachma  Weight 2,09 g, diameter 15 mm. A bilingual coin with
# legends in Greek and Kharoshthi.  Waga 2,09 g, średnica 15 mm. Ciemna
# patyna podkreślająca detale reliefu. Awers: Azes jadący na koniu w
# prawo, wokół legenda w języku greckim BAΣIΛEΩΣ BAΣIΛEΩN MEΓAΛOY AZOY.
# Rewers: Zeus stojący w lewo, trzymający małą Nike na wyciągniętej
# dłoni i długie berło, w polu monogramy, wokół legenda w języku
# kharoshthi.Reference: HGC 12, 655 Grade: VF+  Starting pric... 8 Feb
# 2026 29 EUR The Coin Cabinet - Ancients Auction 31, Lot 56 ANCIENT
# GREECE. INDO-GREEK KINGDOM. Menander I 'Soter'.  Silver Drachm, circa
# 155-130 BC.  Obv: BAΣIΛEΩΣ ΣΩTHPOΣ MENANΔPOY, diademed and draped bust
# right, wearing crested helmet adorned with bull's horn and ear. Rev:
# Athena Alkidemos advancing left, shield decorated with aegis over arm,
# hurling thunderbolt; monogram in right field, Karosthi script around.
# Good Very Fine.  Reference: Bopearachchi-16C; SNG ANS-855; HGC 12-193.
# Weight: 2.35g. Diameter: 16mm. Die Axis: 12h.  PLEASE NOTE: A 20.00...
# 5 Feb 2026 130 GBP Need access to more market information? Research
# tools for professionals Classical Numismatic Group - Electronic
# Auction 603, Lot 359 BAKTRIA, Indo-Greek Kingdom. Menander I Soter.
# Circa 155-130 BC. AR Drachm (17.5mm, 2.47 g, 11h). Diademed and draped
# bust right / Athena Alkidemos standing left; monograms to left, E to
# right. Bopearachchi 13J; SNG ANS 805; HGC 12, 191. Iridescent toning.
# Good VF.     Estimate: 100 USD... 4 Feb 2026 120 USD Your search for
# 'indo ' matched 316 lots from auctions added in the last six months.
# Only the first 100 results are shown. To search our full database of
# over 10 million records, please subscribe to CoinArchives Pro . Search
# for 'indo' in upcoming auctions at Copyright © 2026  CoinArchives, LLC
# All source material used by permission. Any copyright remains with the
# original holders. Frequently Asked Questions Contact us To Top

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
